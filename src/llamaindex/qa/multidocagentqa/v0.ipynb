# %% [markdown]
# ### Multi document agent
# In this notebook, we will build a multi-document agent. The architecture is that each document would have its own individual agent and there would be an overachring agent that decides which of the agents to allocate a question to

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# needed only once to download the llama index documentation website
# domain = "docs.llamaindex.ai"
# docs_url = "https://docs.llamaindex.ai/en/latest/"
# !wget -e robots=off --recursive --no-clobber --page-requisites --html-extension --convert-links --restrict-file-names=windows --domains {domain} --no-parent {docs_url}

# %%
from llama_hub.file.unstructured.base import UnstructuredReader
from llama_index.llms.openai import OpenAI
from llama_index.service_context import ServiceContext
from pathlib import Path

# %%
reader = UnstructuredReader()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/kosisochukwuasuzu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/kosisochukwuasuzu/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
all_files_gen = Path("./docs.llamaindex.ai/").rglob("*")
all_files = [f.resolve() for f in all_files_gen]

# %%
len(all_files)
# Out:
# 322

# %%
suffixes = set([file.suffix for file in all_files])

# %%
suffixes
# Out:
# {'', '.css', '.html', '.js'}

# %%
all_html_files = [file for file in all_files if file.suffix.lower() == ".html"]

# %%
len(all_html_files)
# Out:
# 227

# %%
from llama_index.schema import Document

doc_limit = 100

# %%
docs = []
for idx in range(doc_limit):
    f = all_html_files[idx]
    print(f"Idx {idx}/{len(all_html_files)}")
    loaded_doc = reader.load_data(file=f, split_documents=True)
    start_idx = 72
    loaded_doc = Document(
        text= "\n\n".join([d.get_content() for d in loaded_doc[72:]]),
        metadata={"path": str(f)}
    )
    print(loaded_doc.metadata["path"])
    docs.append(loaded_doc)
# Out:
# Idx 0/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/index.html
# Idx 1/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/genindex.html
# Idx 2/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/search.html
# Idx 3/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/understanding.html
# Idx 4/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/using_llms/using_llms.html
# Idx 5/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/using_llms/privacy.html
# Idx 6/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/loading/llamahub.html
# Idx 7/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/loading/loading.html
# Idx 8/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/evaluating/evaluating.html
# Idx 9/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/evaluating/cost_analysis/root.html
# Idx 10/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/evaluating/cost_analysis/usage_pattern.html
# Idx 11/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/storing/storing.html
# Idx 12/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/tracing_and_debugging/tracing_and_debugging.html
# Idx 13/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/indexing/indexing.html
# Idx 14/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/querying/querying.html
# Idx 15/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/apps.html
# Idx 16/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/q_and_a.html
# Idx 17/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/graphs.html
# Idx 18/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/structured_data.html
# Idx 19/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/agents.html
# Idx 20/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/putting_it_all_together.html
# Idx 21/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/q_and_a/terms_definitions_tutorial.html
# Idx 22/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/q_and_a/unified_query.html
# Idx 23/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/structured_data/Airbyte_demo.html
# Idx 24/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/chatbots/building_a_chatbot.html
# Idx 25/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/apps/fullstack_app_guide.html
# Idx 26/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/apps/fullstack_with_delphic.html
# Idx 27/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/vector_stores/chroma_auto_retriever.html
# Idx 28/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/vector_stores/SimpleIndexDemoLlama-Local.html
# Idx 29/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/vector_stores/WeaviateIndexDemo-Hybrid.html
# Idx 30/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/vector_stores/PineconeIndexDemo-Hybrid.html
# Idx 31/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/vector_stores/qdrant_hybrid.html
# Idx 32/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/pipeline/query_pipeline_pandas.html
# Idx 33/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/pipeline/query_pipeline_sql.html
# Idx 34/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/retrievers/reciprocal_rerank_fusion.html
# Idx 35/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/retrievers/deep_memory.html
# Idx 36/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/retrievers/router_retriever.html
# Idx 37/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/retrievers/bm25_retriever.html
# Idx 38/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/retrievers/auto_vs_recursive_retriever.html
# Idx 39/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/retrievers/composable_retrievers.html
# Idx 40/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/ingestion/async_ingestion_pipeline.html
# Idx 41/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/ingestion/parallel_execution_ingestion_pipeline.html
# Idx 42/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/ingestion/document_management_pipeline.html
# Idx 43/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/ingestion/ingestion_gdrive.html
# Idx 44/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/ingestion/advanced_ingestion_pipeline.html
# Idx 45/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/ingestion/redis_ingestion_pipeline.html
# Idx 46/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/llama_2_llama_cpp.html
# Idx 47/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/localai.html
# Idx 48/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/bedrock.html
# Idx 49/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/gradient_base_model.html
# Idx 50/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/langchain.html
# Idx 51/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/litellm.html
# Idx 52/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/anyscale.html
# Idx 53/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/cohere.html
# Idx 54/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/monsterapi.html
# Idx 55/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/everlyai.html
# Idx 56/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/gradient_model_adapter.html
# Idx 57/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/ai21.html
# Idx 58/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/llama_api.html
# Idx 59/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/clarifai.html
# Idx 60/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/mistralai.html
# Idx 61/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/konko.html
# Idx 62/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/anthropic.html
# Idx 63/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/customization/llms/SimpleIndexDemo-Huggingface_stablelm.html
# Idx 64/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/customization/llms/SimpleIndexDemo-Huggingface_camel.html
# Idx 65/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/metadata_extraction/MetadataExtraction_LLMSurvey.html
# Idx 66/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/metadata_extraction/MarvinMetadataExtractorDemo.html
# Idx 67/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/metadata_extraction/MetadataExtractionSEC.html
# Idx 68/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/metadata_extraction/EntityExtractionClimate.html
# Idx 69/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/metadata_extraction/PydanticExtractor.html
# Idx 70/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/multi_tenancy/multi_tenancy_rag.html
# Idx 71/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/output_parsing/LangchainOutputParserDemo.html
# Idx 72/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/output_parsing/llm_program.html
# Idx 73/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/output_parsing/GuardrailsDemo.html
# Idx 74/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/output_parsing/openai_pydantic_program.html
# Idx 75/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/output_parsing/df_program.html
# Idx 76/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/output_parsing/guidance_pydantic_program.html
# Idx 77/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/output_parsing/guidance_sub_question.html
# Idx 78/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/output_parsing/evaporate_program.html
# Idx 79/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/openai_agent.html
# Idx 80/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/openai_agent_parallel_function_calling.html
# Idx 81/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/multi_document_agents.html
# Idx 82/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/openai_agent_query_plan.html
# Idx 83/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/custom_agent.html
# Idx 84/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/openai_agent_retrieval.html
# Idx 85/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/openai_retrieval_benchmark.html
# Idx 86/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/openai_forced_function_call.html
# Idx 87/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/openai_agent_context_retrieval.html
# Idx 88/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/openai_agent_query_cookbook.html
# Idx 89/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/react_agent.html
# Idx 90/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/agent_builder.html
# Idx 91/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/openai_assistant_query_cookbook.html
# Idx 92/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/openai_agent_with_query_engine.html
# Idx 93/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/react_agent_with_query_engine.html
# Idx 94/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/openai_assistant_agent.html
# Idx 95/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner.html
# Idx 96/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner_rag_controllable.html
# Idx 97/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner_rag.html
# Idx 98/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/agent_runner/query_pipeline_agent.html
# Idx 99/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/finetuning/openai_fine_tuning_functions.html

# %%
llm = OpenAI(model="mistralai/Mixtral-8x7B-Instruct-v0.1", temperature=0.0)
service_context = ServiceContext.from_defaults(llm=llm)

# %%
from llama_index.indices.vector_store import VectorStoreIndex
from llama_index.indices.list.base import SummaryIndex

# %%
import nest_asyncio

nest_asyncio.apply()

# %% [markdown]
# #### Building document agent for each html document
# This means we will have ~227 agents. We define two query engines on each document, we have the semantic search engine the summaraization engine, these are then passed to the agent as tools, we would be using openais function calling capability to acheive this

# %%
from llama_index.agent.openai.base import OpenAIAgent
from llama_index.indices.loading import load_index_from_storage
from llama_index.storage import StorageContext
from llama_index.tools.query_engine import QueryEngineTool
from llama_index.tools.types import ToolMetadata
from llama_index.node_parser import SentenceSplitter
import os
from tqdm import tqdm
import pickle

# %%
from textwrap import dedent

# %%
async def build_agent_per_doc(nodes, file_base):
    print(file_base)
    vi_out_path = f"./data/llamaindex_docs/{file_base}" # output path for vector index
    summary_out_path = f"./data/llamaindex_docs/{file_base}_summary.pkl" # output file for summary index
    
    if not os.path.exists(vi_out_path):
        Path("./data/llamaindex_docs/").mkdir(parents=True, exist_ok=True)
        vector_index = VectorStoreIndex(nodes, service_context=service_context)
        vector_index.storage_context.persist(persist_dir=vi_out_path)
        
    else:
        vector_index = load_index_from_storage(StorageContext.from_defaults(persist_dir=vi_out_path),
                                               service_context=service_context)
    
    # build the summary index
    summary_index = SummaryIndex(nodes, service_context=service_context)
    
    vector_query_engine = vector_index.as_query_engine()
    summary_query_engine = summary_index.as_query_engine(response_mode="tree_summarize")
    
    if not os.path.exists(summary_out_path):
        Path(summary_out_path).parent.mkdir(parents=True, exist_ok=True)
        summary = str(
            await summary_query_engine.aquery(
                "Extract a concise 1-2 line summary of this document"
            )
        )
        pickle.dump(summary, open(summary_out_path, "wb"))
    else:
        summary = pickle.load(open(summary_out_path, "rb"))
        
    query_tools = [
        QueryEngineTool(query_engine=vector_query_engine,
                        metadata=ToolMetadata(
                            name=f"vector_tool_{file_base}",
                            description=f"Useful for questions related to specific facts"
                )),
         QueryEngineTool(query_engine=summary_query_engine,
                        metadata=ToolMetadata(
                            name=f"summary_tool_{file_base}",
                            description=f"Useful for summarization questions",
                            )),

    ]
    
    function_llm = OpenAI(model="mistralai/Mixtral-8x7B-Instruct-v0.1")
 
    agent = OpenAIAgent.from_llm(
        llm=function_llm,
        tools=query_tools,
        verbose=True,
        # system_prompt=dedent(f"""\
        #     You are a specialized agent designed to answer queries about the `{file_base}.html` part of the LlamaIndex docs.
        #     You must ALWAYS use at least one of the tools provided when answering a question; do NOT rely on prior knowledge.\
        #     """),
    )
    
    return agent, summary

# %%
async def build_agents(docs):
    node_parser = SentenceSplitter()
    
    agents_dict = {}
    extract_info_dict = {}
    
    for idx, doc in enumerate(tqdm(docs)):
        nodes = node_parser.get_nodes_from_documents([doc])
        # ID will be base + parent
        file_path = Path(doc.metadata["path"])
        file_base = str(file_path.parent.stem) + "_" + str(file_path.stem)
        agent, summary = await build_agent_per_doc(nodes, file_base)
        
        agents_dict[file_base] = agent
        extract_info_dict[file_base] = {"summary": summary, "nodes": nodes}
        
    return agents_dict, extract_info_dict

# %%
agents_dict, extra_info_dict = await build_agents(docs[:7])
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# latest_index
# latest_genindex
#  14%|█▍        | 1/7 [12:00<1:12:03, 720.65s/it]
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     125 self._sock.settimeout(timeout)
# --> 126 return self._sock.recv(max_bytes)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1296, in SSLSocket.recv(self, buflen, flags)
#    1293         raise ValueError(
#    1294             "non-zero flags not allowed in calls to recv() on %s" %
#    1295             self.__class__)
# -> 1296     return self.read(buflen)
#    1297 else:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1169, in SSLSocket.read(self, len, buffer)
#    1168     else:
# -> 1169         return self._sslobj.read(len)
#    1170 except SSLError as x:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeout                               Traceback (most recent call last)
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_transports/default.py:67, in map_httpcore_exceptions()
#      66 try:
# ---> 67     yield
#      68 except Exception as exc:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_transports/default.py:231, in HTTPTransport.handle_request(self, request)
#     230 with map_httpcore_exceptions():
# --> 231     resp = self._pool.handle_request(req)
#     233 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:111, in HTTP11Connection.handle_request(self, request)
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_backends/sync.py:124, in SyncStream.read(self, max_bytes, timeout)
#     123 exc_map: ExceptionMapping = {socket.timeout: ReadTimeout, OSError: ReadError}
# --> 124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ReadTimeout: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeout                               Traceback (most recent call last)
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/openai/_base_client.py:918, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     917 try:
# --> 918     response = self._client.send(
#     919         request,
#     920         stream=stream or self._should_stream_response_body(request=request),
#     921         **kwargs,
#     922     )
#     923 except httpx.TimeoutException as err:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_client.py:915, in Client.send(self, request, stream, auth, follow_redirects)
#     913 auth = self._build_request_auth(request, auth)
# --> 915 response = self._send_handling_auth(
#     916     request,
#     917     auth=auth,
#     918     follow_redirects=follow_redirects,
#     919     history=[],
#     920 )
#     921 try:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_client.py:943, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     942 while True:
# --> 943     response = self._send_handling_redirects(
#     944         request,
#     945         follow_redirects=follow_redirects,
#     946         history=history,
#     947     )
#     948     try:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_client.py:980, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     978     hook(request)
# --> 980 response = self._send_single_request(request)
#     981 try:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_client.py:1016, in Client._send_single_request(self, request)
#    1015 with request_context(request=request):
# -> 1016     response = transport.handle_request(request)
#    1018 assert isinstance(response.stream, SyncByteStream)
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_transports/default.py:230, in HTTPTransport.handle_request(self, request)
#     218 req = httpcore.Request(
#     219     method=request.method,
#     220     url=httpcore.URL(
#    (...)
#     228     extensions=request.extensions,
#     229 )
# --> 230 with map_httpcore_exceptions():
#     231     resp = self._pool.handle_request(req)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_transports/default.py:84, in map_httpcore_exceptions()
#      83 message = str(exc)
# ---> 84 raise mapped_exc(message) from exc
#
# ReadTimeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     125 self._sock.settimeout(timeout)
# --> 126 return self._sock.recv(max_bytes)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1296, in SSLSocket.recv(self, buflen, flags)
#    1293         raise ValueError(
#    1294             "non-zero flags not allowed in calls to recv() on %s" %
#    1295             self.__class__)
# -> 1296     return self.read(buflen)
#    1297 else:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1169, in SSLSocket.read(self, len, buffer)
#    1168     else:
# -> 1169         return self._sslobj.read(len)
#    1170 except SSLError as x:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeout                               Traceback (most recent call last)
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_transports/default.py:67, in map_httpcore_exceptions()
#      66 try:
# ---> 67     yield
#      68 except Exception as exc:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_transports/default.py:231, in HTTPTransport.handle_request(self, request)
#     230 with map_httpcore_exceptions():
# --> 231     resp = self._pool.handle_request(req)
#     233 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:111, in HTTP11Connection.handle_request(self, request)
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_backends/sync.py:124, in SyncStream.read(self, max_bytes, timeout)
#     123 exc_map: ExceptionMapping = {socket.timeout: ReadTimeout, OSError: ReadError}
# --> 124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ReadTimeout: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeout                               Traceback (most recent call last)
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/openai/_base_client.py:918, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     917 try:
# --> 918     response = self._client.send(
#     919         request,
#     920         stream=stream or self._should_stream_response_body(request=request),
#     921         **kwargs,
#     922     )
#     923 except httpx.TimeoutException as err:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_client.py:915, in Client.send(self, request, stream, auth, follow_redirects)
#     913 auth = self._build_request_auth(request, auth)
# --> 915 response = self._send_handling_auth(
#     916     request,
#     917     auth=auth,
#     918     follow_redirects=follow_redirects,
#     919     history=[],
#     920 )
#     921 try:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_client.py:943, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     942 while True:
# --> 943     response = self._send_handling_redirects(
#     944         request,
#     945         follow_redirects=follow_redirects,
#     946         history=history,
#     947     )
#     948     try:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_client.py:980, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     978     hook(request)
# --> 980 response = self._send_single_request(request)
#     981 try:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_client.py:1016, in Client._send_single_request(self, request)
#    1015 with request_context(request=request):
# -> 1016     response = transport.handle_request(request)
#    1018 assert isinstance(response.stream, SyncByteStream)
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_transports/default.py:230, in HTTPTransport.handle_request(self, request)
#     218 req = httpcore.Request(
#     219     method=request.method,
#     220     url=httpcore.URL(
#    (...)
#     228     extensions=request.extensions,
#     229 )
# --> 230 with map_httpcore_exceptions():
#     231     resp = self._pool.handle_request(req)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_transports/default.py:84, in map_httpcore_exceptions()
#      83 message = str(exc)
# ---> 84 raise mapped_exc(message) from exc
#
# ReadTimeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     125 self._sock.settimeout(timeout)
# --> 126 return self._sock.recv(max_bytes)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1296, in SSLSocket.recv(self, buflen, flags)
#    1293         raise ValueError(
#    1294             "non-zero flags not allowed in calls to recv() on %s" %
#    1295             self.__class__)
# -> 1296     return self.read(buflen)
#    1297 else:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1169, in SSLSocket.read(self, len, buffer)
#    1168     else:
# -> 1169         return self._sslobj.read(len)
#    1170 except SSLError as x:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeout                               Traceback (most recent call last)
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_transports/default.py:67, in map_httpcore_exceptions()
#      66 try:
# ---> 67     yield
#      68 except Exception as exc:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_transports/default.py:231, in HTTPTransport.handle_request(self, request)
#     230 with map_httpcore_exceptions():
# --> 231     resp = self._pool.handle_request(req)
#     233 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:111, in HTTP11Connection.handle_request(self, request)
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_backends/sync.py:124, in SyncStream.read(self, max_bytes, timeout)
#     123 exc_map: ExceptionMapping = {socket.timeout: ReadTimeout, OSError: ReadError}
# --> 124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ReadTimeout: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeout                               Traceback (most recent call last)
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/openai/_base_client.py:918, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     917 try:
# --> 918     response = self._client.send(
#     919         request,
#     920         stream=stream or self._should_stream_response_body(request=request),
#     921         **kwargs,
#     922     )
#     923 except httpx.TimeoutException as err:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_client.py:915, in Client.send(self, request, stream, auth, follow_redirects)
#     913 auth = self._build_request_auth(request, auth)
# --> 915 response = self._send_handling_auth(
#     916     request,
#     917     auth=auth,
#     918     follow_redirects=follow_redirects,
#     919     history=[],
#     920 )
#     921 try:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_client.py:943, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     942 while True:
# --> 943     response = self._send_handling_redirects(
#     944         request,
#     945         follow_redirects=follow_redirects,
#     946         history=history,
#     947     )
#     948     try:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_client.py:980, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     978     hook(request)
# --> 980 response = self._send_single_request(request)
#     981 try:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_client.py:1016, in Client._send_single_request(self, request)
#    1015 with request_context(request=request):
# -> 1016     response = transport.handle_request(request)
#    1018 assert isinstance(response.stream, SyncByteStream)
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_transports/default.py:230, in HTTPTransport.handle_request(self, request)
#     218 req = httpcore.Request(
#     219     method=request.method,
#     220     url=httpcore.URL(
#    (...)
#     228     extensions=request.extensions,
#     229 )
# --> 230 with map_httpcore_exceptions():
#     231     resp = self._pool.handle_request(req)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_transports/default.py:84, in map_httpcore_exceptions()
#      83 message = str(exc)
# ---> 84 raise mapped_exc(message) from exc
#
# ReadTimeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     125 self._sock.settimeout(timeout)
# --> 126 return self._sock.recv(max_bytes)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1296, in SSLSocket.recv(self, buflen, flags)
#    1293         raise ValueError(
#    1294             "non-zero flags not allowed in calls to recv() on %s" %
#    1295             self.__class__)
# -> 1296     return self.read(buflen)
#    1297 else:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1169, in SSLSocket.read(self, len, buffer)
#    1168     else:
# -> 1169         return self._sslobj.read(len)
#    1170 except SSLError as x:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeout                               Traceback (most recent call last)
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_transports/default.py:67, in map_httpcore_exceptions()
#      66 try:
# ---> 67     yield
#      68 except Exception as exc:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_transports/default.py:231, in HTTPTransport.handle_request(self, request)
#     230 with map_httpcore_exceptions():
# --> 231     resp = self._pool.handle_request(req)
#     233 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:111, in HTTP11Connection.handle_request(self, request)
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_backends/sync.py:124, in SyncStream.read(self, max_bytes, timeout)
#     123 exc_map: ExceptionMapping = {socket.timeout: ReadTimeout, OSError: ReadError}
# --> 124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ReadTimeout: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeout                               Traceback (most recent call last)
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/openai/_base_client.py:918, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     917 try:
# --> 918     response = self._client.send(
#     919         request,
#     920         stream=stream or self._should_stream_response_body(request=request),
#     921         **kwargs,
#     922     )
#     923 except httpx.TimeoutException as err:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_client.py:915, in Client.send(self, request, stream, auth, follow_redirects)
#     913 auth = self._build_request_auth(request, auth)
# --> 915 response = self._send_handling_auth(
#     916     request,
#     917     auth=auth,
#     918     follow_redirects=follow_redirects,
#     919     history=[],
#     920 )
#     921 try:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_client.py:943, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     942 while True:
# --> 943     response = self._send_handling_redirects(
#     944         request,
#     945         follow_redirects=follow_redirects,
#     946         history=history,
#     947     )
#     948     try:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_client.py:980, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     978     hook(request)
# --> 980 response = self._send_single_request(request)
#     981 try:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_client.py:1016, in Client._send_single_request(self, request)
#    1015 with request_context(request=request):
# -> 1016     response = transport.handle_request(request)
#    1018 assert isinstance(response.stream, SyncByteStream)
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_transports/default.py:230, in HTTPTransport.handle_request(self, request)
#     218 req = httpcore.Request(
#     219     method=request.method,
#     220     url=httpcore.URL(
#    (...)
#     228     extensions=request.extensions,
#     229 )
# --> 230 with map_httpcore_exceptions():
#     231     resp = self._pool.handle_request(req)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_transports/default.py:84, in map_httpcore_exceptions()
#      83 message = str(exc)
# ---> 84 raise mapped_exc(message) from exc
#
# ReadTimeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     125 self._sock.settimeout(timeout)
# --> 126 return self._sock.recv(max_bytes)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1296, in SSLSocket.recv(self, buflen, flags)
#    1293         raise ValueError(
#    1294             "non-zero flags not allowed in calls to recv() on %s" %
#    1295             self.__class__)
# -> 1296     return self.read(buflen)
#    1297 else:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1169, in SSLSocket.read(self, len, buffer)
#    1168     else:
# -> 1169         return self._sslobj.read(len)
#    1170 except SSLError as x:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeout                               Traceback (most recent call last)
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_transports/default.py:67, in map_httpcore_exceptions()
#      66 try:
# ---> 67     yield
#      68 except Exception as exc:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_transports/default.py:231, in HTTPTransport.handle_request(self, request)
#     230 with map_httpcore_exceptions():
# --> 231     resp = self._pool.handle_request(req)
#     233 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:111, in HTTP11Connection.handle_request(self, request)
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_backends/sync.py:124, in SyncStream.read(self, max_bytes, timeout)
#     123 exc_map: ExceptionMapping = {socket.timeout: ReadTimeout, OSError: ReadError}
# --> 124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ReadTimeout: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeout                               Traceback (most recent call last)
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/openai/_base_client.py:918, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     917 try:
# --> 918     response = self._client.send(
#     919         request,
#     920         stream=stream or self._should_stream_response_body(request=request),
#     921         **kwargs,
#     922     )
#     923 except httpx.TimeoutException as err:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_client.py:915, in Client.send(self, request, stream, auth, follow_redirects)
#     913 auth = self._build_request_auth(request, auth)
# --> 915 response = self._send_handling_auth(
#     916     request,
#     917     auth=auth,
#     918     follow_redirects=follow_redirects,
#     919     history=[],
#     920 )
#     921 try:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_client.py:943, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     942 while True:
# --> 943     response = self._send_handling_redirects(
#     944         request,
#     945         follow_redirects=follow_redirects,
#     946         history=history,
#     947     )
#     948     try:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_client.py:980, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     978     hook(request)
# --> 980 response = self._send_single_request(request)
#     981 try:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_client.py:1016, in Client._send_single_request(self, request)
#    1015 with request_context(request=request):
# -> 1016     response = transport.handle_request(request)
#    1018 assert isinstance(response.stream, SyncByteStream)
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_transports/default.py:230, in HTTPTransport.handle_request(self, request)
#     218 req = httpcore.Request(
#     219     method=request.method,
#     220     url=httpcore.URL(
#    (...)
#     228     extensions=request.extensions,
#     229 )
# --> 230 with map_httpcore_exceptions():
#     231     resp = self._pool.handle_request(req)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_transports/default.py:84, in map_httpcore_exceptions()
#      83 message = str(exc)
# ---> 84 raise mapped_exc(message) from exc
#
# ReadTimeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     125 self._sock.settimeout(timeout)
# --> 126 return self._sock.recv(max_bytes)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1296, in SSLSocket.recv(self, buflen, flags)
#    1293         raise ValueError(
#    1294             "non-zero flags not allowed in calls to recv() on %s" %
#    1295             self.__class__)
# -> 1296     return self.read(buflen)
#    1297 else:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1169, in SSLSocket.read(self, len, buffer)
#    1168     else:
# -> 1169         return self._sslobj.read(len)
#    1170 except SSLError as x:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeout                               Traceback (most recent call last)
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_transports/default.py:67, in map_httpcore_exceptions()
#      66 try:
# ---> 67     yield
#      68 except Exception as exc:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpx/_transports/default.py:231, in HTTPTransport.handle_request(self, request)
#     230 with map_httpcore_exceptions():
# --> 231     resp = self._pool.handle_request(req)
#     233 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# ...
#
# The above exception was the direct cause of the following exception:
#
# APITimeoutError                           Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 agents_dict, extra_info_dict = await build_agents(docs[:7])
#
# Cell In[23], line 12, in build_agents(docs)
#      10 file_path = Path(doc.metadata["path"])
#      11 file_base = str(file_path.parent.stem) + "_" + str(file_path.stem)
# ---> 12 agent, summary = await build_agent_per_doc(nodes, file_base)
#      14 agents_dict[file_base] = agent
#      15 extract_info_dict[file_base] = {"summary": summary, "nodes": nodes}
#
# Cell In[22], line 8, in build_agent_per_doc(nodes, file_base)
#       6 if not os.path.exists(vi_out_path):
#       7     Path("./data/llamaindex_docs/").mkdir(parents=True, exist_ok=True)
# ----> 8     vector_index = VectorStoreIndex(nodes, service_context=service_context)
#       9     vector_index.storage_context.persist(persist_dir=vi_out_path)
#      11 else:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/llama_index/indices/vector_store/base.py:53, in VectorStoreIndex.__init__(self, nodes, objects, index_struct, service_context, storage_context, use_async, store_nodes_override, insert_batch_size, show_progress, **kwargs)
#      51 self._store_nodes_override = store_nodes_override
#      52 self._insert_batch_size = insert_batch_size
# ---> 53 super().__init__(
#      54     nodes=nodes,
#      55     index_struct=index_struct,
#      56     service_context=service_context,
#      57     storage_context=storage_context,
#      58     show_progress=show_progress,
#      59     objects=objects,
#      60     **kwargs,
#      61 )
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/llama_index/indices/base.py:73, in BaseIndex.__init__(self, nodes, objects, index_struct, storage_context, service_context, show_progress, **kwargs)
#      71 if index_struct is None:
#      72     nodes = nodes or []
# ---> 73     index_struct = self.build_index_from_nodes(
#      74         nodes + objects  # type: ignore
#      75     )
#      76 self._index_struct = index_struct
#      77 self._storage_context.index_store.add_index_struct(self._index_struct)
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/llama_index/indices/vector_store/base.py:274, in VectorStoreIndex.build_index_from_nodes(self, nodes, **insert_kwargs)
#     266 if any(
#     267     node.get_content(metadata_mode=MetadataMode.EMBED) == "" for node in nodes
#     268 ):
#     269     raise ValueError(
#     270         "Cannot build index from nodes with no content. "
#     271         "Please ensure all nodes have content."
#     272     )
# --> 274 return self._build_index_from_nodes(nodes, **insert_kwargs)
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/llama_index/indices/vector_store/base.py:246, in VectorStoreIndex._build_index_from_nodes(self, nodes, **insert_kwargs)
#     244     run_async_tasks(tasks)
#     245 else:
# --> 246     self._add_nodes_to_index(
#     247         index_struct,
#     248         nodes,
#     249         show_progress=self._show_progress,
#     250         **insert_kwargs,
#     251     )
#     252 return index_struct
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/llama_index/indices/vector_store/base.py:199, in VectorStoreIndex._add_nodes_to_index(self, index_struct, nodes, show_progress, **insert_kwargs)
#     196     return
#     198 for nodes_batch in iter_batch(nodes, self._insert_batch_size):
# --> 199     nodes_batch = self._get_node_with_embedding(nodes_batch, show_progress)
#     200     new_ids = self._vector_store.add(nodes_batch, **insert_kwargs)
#     202     if not self._vector_store.stores_text or self._store_nodes_override:
#     203         # NOTE: if the vector store doesn't store text,
#     204         # we need to add the nodes to the index struct and document store
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/llama_index/indices/vector_store/base.py:107, in VectorStoreIndex._get_node_with_embedding(self, nodes, show_progress)
#      96 def _get_node_with_embedding(
#      97     self,
#      98     nodes: Sequence[BaseNode],
#      99     show_progress: bool = False,
#     100 ) -> List[BaseNode]:
#     101     """Get tuples of id, node, and embedding.
#     102
#     103     Allows us to store these nodes in a vector store.
#     104     Embeddings are called in batches.
#     105
#     106     """
# --> 107     id_to_embed_map = embed_nodes(
#     108         nodes, self._service_context.embed_model, show_progress=show_progress
#     109     )
#     111     results = []
#     112     for node in nodes:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/llama_index/indices/utils.py:137, in embed_nodes(nodes, embed_model, show_progress)
#     134     else:
#     135         id_to_embed_map[node.node_id] = node.embedding
# --> 137 new_embeddings = embed_model.get_text_embedding_batch(
#     138     texts_to_embed, show_progress=show_progress
#     139 )
#     141 for new_id, text_embedding in zip(ids_to_embed, new_embeddings):
#     142     id_to_embed_map[new_id] = text_embedding
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/llama_index/core/embeddings/base.py:256, in BaseEmbedding.get_text_embedding_batch(self, texts, show_progress, **kwargs)
#     250 if idx == len(texts) - 1 or len(cur_batch) == self.embed_batch_size:
#     251     # flush
#     252     with self.callback_manager.event(
#     253         CBEventType.EMBEDDING,
#     254         payload={EventPayload.SERIALIZED: self.to_dict()},
#     255     ) as event:
# --> 256         embeddings = self._get_text_embeddings(cur_batch)
#     257         result_embeddings.extend(embeddings)
#     258         event.on_end(
#     259             payload={
#     260                 EventPayload.CHUNKS: cur_batch,
#     261                 EventPayload.EMBEDDINGS: embeddings,
#     262             },
#     263         )
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/llama_index/embeddings/openai.py:413, in OpenAIEmbedding._get_text_embeddings(self, texts)
#     406 """Get text embeddings.
#     407
#     408 By default, this is a wrapper around _get_text_embedding.
#     409 Can be overridden for batch queries.
#     410
#     411 """
#     412 client = self._get_client()
# --> 413 return get_embeddings(
#     414     client,
#     415     texts,
#     416     engine="togethercomputer/m2-bert-80M-32k-retrieval",
#     417     # engine=self._text_engine,
#     418     **self.additional_kwargs,
#     419 )
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/tenacity/__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/tenacity/__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/tenacity/__init__.py:325, in BaseRetrying.iter(self, retry_state)
#     323     retry_exc = self.retry_error_cls(fut)
#     324     if self.reraise:
# --> 325         raise retry_exc.reraise()
#     326     raise retry_exc from fut.exception()
#     328 if self.wait:
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/tenacity/__init__.py:158, in RetryError.reraise(self)
#     156 def reraise(self) -> t.NoReturn:
#     157     if self.last_attempt.failed:
# --> 158         raise self.last_attempt.result()
#     159     raise self
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/tenacity/__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     380 if isinstance(do, DoAttempt):
#     381     try:
# --> 382         result = fn(*args, **kwargs)
#     383     except BaseException:  # noqa: B902
#     384         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/llama_index/embeddings/openai.py:178, in get_embeddings(client, list_of_text, engine, **kwargs)
#     174 assert len(list_of_text) <= 2048, "The batch size should not be larger than 2048."
#     176 list_of_text = [text.replace("\n", " ") for text in list_of_text]
# --> 178 data = client.embeddings.create(input=list_of_text, model=engine, **kwargs).data
#     179 return [d.embedding for d in data]
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/openai/resources/embeddings.py:113, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     111     return obj
#     112 del params["encoding_format"]
# --> 113 return self._post(
#     114     "/embeddings",
#     115     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     116     options=make_request_options(
#     117         extra_headers=extra_headers,
#     118         extra_query=extra_query,
#     119         extra_body=extra_body,
#     120         timeout=timeout,
#     121         post_parser=parser,
#     122     ),
#     123     cast_to=CreateEmbeddingResponse,
#     124 )
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/openai/_base_client.py:1200, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1186 def post(
#    1187     self,
#    1188     path: str,
#    (...)
#    1195     stream_cls: type[_StreamT] | None = None,
#    1196 ) -> ResponseT | _StreamT:
#    1197     opts = FinalRequestOptions.construct(
#    1198         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1199     )
# -> 1200     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/openai/_base_client.py:889, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     880 def request(
#     881     self,
#     882     cast_to: Type[ResponseT],
#    (...)
#     887     stream_cls: type[_StreamT] | None = None,
#     888 ) -> ResponseT | _StreamT:
# --> 889     return self._request(
#     890         cast_to=cast_to,
#     891         options=options,
#     892         stream=stream,
#     893         stream_cls=stream_cls,
#     894         remaining_retries=remaining_retries,
#     895     )
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/openai/_base_client.py:927, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     924 log.debug("Encountered httpx.TimeoutException", exc_info=True)
#     926 if retries > 0:
# --> 927     return self._retry_request(
#     928         options,
#     929         cast_to,
#     930         retries,
#     931         stream=stream,
#     932         stream_cls=stream_cls,
#     933         response_headers=None,
#     934     )
#     936 log.debug("Raising timeout error")
#     937 raise APITimeoutError(request=request) from err
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/openai/_base_client.py:1013, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1009 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1010 # different thread if necessary.
#    1011 time.sleep(timeout)
# -> 1013 return self._request(
#    1014     options=options,
#    1015     cast_to=cast_to,
#    1016     remaining_retries=remaining,
#    1017     stream=stream,
#    1018     stream_cls=stream_cls,
#    1019 )
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/openai/_base_client.py:927, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     924 log.debug("Encountered httpx.TimeoutException", exc_info=True)
#     926 if retries > 0:
# --> 927     return self._retry_request(
#     928         options,
#     929         cast_to,
#     930         retries,
#     931         stream=stream,
#     932         stream_cls=stream_cls,
#     933         response_headers=None,
#     934     )
#     936 log.debug("Raising timeout error")
#     937 raise APITimeoutError(request=request) from err
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/openai/_base_client.py:1013, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1009 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1010 # different thread if necessary.
#    1011 time.sleep(timeout)
# -> 1013 return self._request(
#    1014     options=options,
#    1015     cast_to=cast_to,
#    1016     remaining_retries=remaining,
#    1017     stream=stream,
#    1018     stream_cls=stream_cls,
#    1019 )
#
#     [... skipping similar frames: SyncAPIClient._request at line 927 (7 times), SyncAPIClient._retry_request at line 1013 (7 times)]
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/openai/_base_client.py:927, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     924 log.debug("Encountered httpx.TimeoutException", exc_info=True)
#     926 if retries > 0:
# --> 927     return self._retry_request(
#     928         options,
#     929         cast_to,
#     930         retries,
#     931         stream=stream,
#     932         stream_cls=stream_cls,
#     933         response_headers=None,
#     934     )
#     936 log.debug("Raising timeout error")
#     937 raise APITimeoutError(request=request) from err
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/openai/_base_client.py:1013, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1009 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1010 # different thread if necessary.
#    1011 time.sleep(timeout)
# -> 1013 return self._request(
#    1014     options=options,
#    1015     cast_to=cast_to,
#    1016     remaining_retries=remaining,
#    1017     stream=stream,
#    1018     stream_cls=stream_cls,
#    1019 )
#
# File ~/Developer/ai-startups/test-demos/pdfchat/venv/lib/python3.11/site-packages/openai/_base_client.py:937, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     927         return self._retry_request(
#     928             options,
#     929             cast_to,
#    (...)
#     933             response_headers=None,
#     934         )
#     936     log.debug("Raising timeout error")
# --> 937     raise APITimeoutError(request=request) from err
#     938 except Exception as err:
#     939     log.debug("Encountered Exception", exc_info=True)
#
# APITimeoutError: Request timed out.

# %% [markdown]
# #### Next we will build the retreiver enabled OpenAI agent
# We are going to build the top level agent that orchestrates the use of the other agents to answer user queries

# %%
all_tools = []

for file_base, agent in agents_dict.items():
    summary = extra_info_dict[file_base]["summary"]
    doc_tool = QueryEngineTool(
        query_engine=agent, 
        metadata=ToolMetadata(
            name=f"tool_{file_base}",
            description=summary,
        )
    )
    all_tools.append(doc_tool)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 all_tools = []
# ----> 3 for file_base, agent in agents_dict.items():
#       4     summary = extra_info_dict[file_base]["summary"]
#       5     doc_tool = QueryEngineTool(
#       6         query_engine=agent,
#       7         metadata=ToolMetadata(
#    (...)
#      10         )
#      11     )
#
# NameError: name 'agents_dict' is not defined

# %%
from llama_index.objects import ObjectIndex, SimpleToolNodeMapping, ObjectRetriever
from llama_index.retrievers import BaseRetriever
from llama_index.postprocessor import CohereRerank
from llama_index.tools import QueryPlanTool
from llama_index.query_engine import SubQuestionQueryEngine

# %%
llm = OpenAI(model="mistralai/Mixtral-8x7B-Instruct-v0.1")

# %%
tool_mapping = SimpleToolNodeMapping.from_objects(all_tools)
obj_index = ObjectIndex.from_objects(
    all_tools, 
    tool_mapping,
    VectorStoreIndex
)

vector_node_retreiver = obj_index.as_node_retriever(similarity_top_k=10)

# %%
# define custom tretreivers with reranking. Why don't we add this as a postprocessor to our current retrevier
class CustomRetrevier(BaseRetriever):
    def __init__(self, vector_retriever, postprocessor):
        self._vector_retriever = vector_retriever
        self._postprocessor = postprocessor or CohereRerank(top_n=5)
        super().__init__()
    
    def _retreive(self, query_bundle):
        retreived_nodes = self._vector_retriever.retreive(query_bundle)
        filtered_nodes = self._postprocessor.postprocess_nodes(retreived_nodes, query_bundle=query_bundle)
        return filtered_nodes

# %%
# define a custom object retreiver that adds in a query planning tool
from typing import List


class CustomObjectRetriever(ObjectRetriever):
    def __init__(self, retriever, object_node_mapping, all_tools, llm=None):
        self._retriever = retriever
        self._object_node_mapping = object_node_mapping
        self._all_tools = all_tools
        self._llm = llm or OpenAI(model="mistralai/Mixtral-8x7B-Instruct-v0.1")
    
    def retrieve(self, query_bundle):
        nodes = self._retriever.retrieve(query_bundle)
        tools = [self._object_node_mapping.from_node(n.node) for n in nodes]
        sub_question_sc = ServiceContext.from_defaults(
            llm=self._llm
        )
        sub_question_engine = SubQuestionQueryEngine.from_defaults(
            query_engine_tools=tools, 
            service_context=sub_question_sc
        )
        sub_question_description = dedent(f"""\
            Useful for any queries that involve comparing multiple documents. ALWAYS use this tool for comparison queries - make sure to call this \
            tool with the original query. Do NOT use the other tools for any queries involving multiple documents.
            """)
        
        sub_question_tool = QueryEngineTool(
            query_engine=sub_question_engine, 
            metadata=ToolMetadata(
                name="compare_tool",
                description=sub_question_description
            )
        )
        
        return tools + [sub_question_tool]

# %%
custom_node_retreiver = CustomRetrevier(vector_node_retreiver)
custom_object_retreiver = CustomObjectRetriever(retriever=custom_node_retreiver, 
                                                object_node_mapping=tool_mapping, 
                                                all_tools=all_tools, 
                                                llm=llm)

# %%
tmps = custom_object_retreiver.retrieve("hello")
print(len(tmps))

# %%
from llama_index.agent import FnRetrieverOpenAIAgent

# %%
agent = FnRetrieverOpenAIAgent.from_retriever(
    retriever=custom_node_retreiver,
    system_prompt=dedent(""" \
    You are an agent designed to answer queries about the documentation.
    Please always use the tools provided to answer a question. Do not rely on prior knowledge.\

    """),
    llm=llm,
    verbose=True,
)

# %% [markdown]
# ##### Creating Naive RAG implementation
# To compare with our agent implementation we would be creating a naive RAG implementation to evaluate the validity of our entire experiment.

# %%
all_nodes = [
    n for extra_info in extra_info_dict.values() for n in extra_info["nodes"]
]

# %%
base_index = VectorStoreIndex(all_nodes)
base_query_engine = base_index.as_query_engine(similarity_top_k=4)

# %%
response = agent.query(
    "Tell me about the different types of evaluation in LlamaIndex"
)

# %%
# baseline
response = base_query_engine.query(
    "Tell me about the different types of evaluation in LlamaIndex"
)
print(str(response))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 # baseline
# ----> 2 response = base_query_engine.query(
#       3     "Tell me about the different types of evaluation in LlamaIndex"
#       4 )
#       5 print(str(response))
#
# NameError: name 'base_query_engine' is not defined
