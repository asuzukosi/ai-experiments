# %% [markdown]
# ### Multi document agent
# In this notebook, we will build a multi-document agent. The architecture is that each document would have its own individual agent and there would be an overachring agent that decides which of the agents to allocate a question to

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# needed only once to download the llama index documentation website
# domain = "docs.llamaindex.ai"
# docs_url = "https://docs.llamaindex.ai/en/latest/"
# !wget -e robots=off --recursive --no-clobber --page-requisites --html-extension --convert-links --restrict-file-names=windows --domains {domain} --no-parent {docs_url}
# Out:
# Both --no-clobber and --convert-links were specified, only --convert-links will be used.
# --2024-02-11 01:28:00--  https://docs.llamaindex.ai/en/latest/
# Resolving docs.llamaindex.ai (docs.llamaindex.ai)... 104.18.1.163, 104.18.0.163
# Connecting to docs.llamaindex.ai (docs.llamaindex.ai)|104.18.1.163|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/index.html’
#
# docs.llamaindex.ai/     [ <=>                ] 226.37K  1.31MB/s    in 0.2s
#
# 2024-02-11 01:28:02 (1.31 MB/s) - ‘docs.llamaindex.ai/en/latest/index.html’ saved [231805]
#
# --2024-02-11 01:28:02--  https://docs.llamaindex.ai/en/latest/genindex.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/genindex.html’
#
# docs.llamaindex.ai/     [     <=>            ]   1002K  1.16MB/s    in 0.8s
#
# 2024-02-11 01:28:03 (1.16 MB/s) - ‘docs.llamaindex.ai/en/latest/genindex.html’ saved [1025749]
#
# --2024-02-11 01:28:03--  https://docs.llamaindex.ai/en/latest/search.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/search.html’
#
# docs.llamaindex.ai/     [ <=>                ] 217.60K  1.16MB/s    in 0.2s
#
# 2024-02-11 01:28:04 (1.16 MB/s) - ‘docs.llamaindex.ai/en/latest/search.html’ saved [222819]
#
# --2024-02-11 01:28:04--  https://docs.llamaindex.ai/en/latest/getting_started/installation.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/getting_started/installation.html’
#
# docs.llamaindex.ai/     [  <=>               ] 227.64K  1.04MB/s    in 0.2s
#
# 2024-02-11 01:28:06 (1.04 MB/s) - ‘docs.llamaindex.ai/en/latest/getting_started/installation.html’ saved [233105]
#
# --2024-02-11 01:28:06--  https://docs.llamaindex.ai/en/latest/_static/pygments.css
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘docs.llamaindex.ai/en/latest/_static/pygments.css’
#
# docs.llamaindex.ai/     [ <=>                ]  20.92K  --.-KB/s    in 0s
#
# 2024-02-11 01:28:06 (454 MB/s) - ‘docs.llamaindex.ai/en/latest/_static/pygments.css’ saved [21424]
#
# --2024-02-11 01:28:06--  https://docs.llamaindex.ai/en/latest/_static/styles/furo.css?digest=fad236701ea90a88636c2a8c73b44ae642ed2a53
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘docs.llamaindex.ai/en/latest/_static/styles/furo.css@digest=fad236701ea90a88636c2a8c73b44ae642ed2a53.css’
#
# docs.llamaindex.ai/     [ <=>                ]  47.56K  --.-KB/s    in 0.02s
#
# 2024-02-11 01:28:07 (2.73 MB/s) - ‘docs.llamaindex.ai/en/latest/_static/styles/furo.css@digest=fad236701ea90a88636c2a8c73b44ae642ed2a53.css’ saved [48697]
#
# --2024-02-11 01:28:07--  https://docs.llamaindex.ai/en/latest/_static/mystnb.4510f1fc1dee50b3e5859aac5469c37c29e427902b24a333a5f9fcb2f0b3ac41.css
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘docs.llamaindex.ai/en/latest/_static/mystnb.4510f1fc1dee50b3e5859aac5469c37c29e427902b24a333a5f9fcb2f0b3ac41.css’
#
# docs.llamaindex.ai/     [ <=>                ]  38.44K  --.-KB/s    in 0.004s
#
# 2024-02-11 01:28:07 (8.97 MB/s) - ‘docs.llamaindex.ai/en/latest/_static/mystnb.4510f1fc1dee50b3e5859aac5469c37c29e427902b24a333a5f9fcb2f0b3ac41.css’ saved [39364]
#
# --2024-02-11 01:28:07--  https://docs.llamaindex.ai/en/latest/_static/autodoc_pydantic.css
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 181 [text/css]
# Saving to: ‘docs.llamaindex.ai/en/latest/_static/autodoc_pydantic.css’
#
# docs.llamaindex.ai/ 100%[===================>]     181  --.-KB/s    in 0s
#
# 2024-02-11 01:28:08 (173 MB/s) - ‘docs.llamaindex.ai/en/latest/_static/autodoc_pydantic.css’ saved [181/181]
#
# --2024-02-11 01:28:08--  https://docs.llamaindex.ai/en/latest/_static/graphviz.css
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘docs.llamaindex.ai/en/latest/_static/graphviz.css’
#
# docs.llamaindex.ai/     [ <=>                ]     299  --.-KB/s    in 0s
#
# 2024-02-11 01:28:09 (285 MB/s) - ‘docs.llamaindex.ai/en/latest/_static/graphviz.css’ saved [299]
#
# --2024-02-11 01:28:09--  https://docs.llamaindex.ai/en/latest/_static/styles/furo-extensions.css?digest=30d1aed668e5c3a91c3e3bf6a60b675221979f0e
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘docs.llamaindex.ai/en/latest/_static/styles/furo-extensions.css@digest=30d1aed668e5c3a91c3e3bf6a60b675221979f0e.css’
#
# docs.llamaindex.ai/     [ <=>                ]   5.40K  --.-KB/s    in 0s
#
# 2024-02-11 01:28:09 (1.03 GB/s) - ‘docs.llamaindex.ai/en/latest/_static/styles/furo-extensions.css@digest=30d1aed668e5c3a91c3e3bf6a60b675221979f0e.css’ saved [5529]
#
# --2024-02-11 01:28:09--  https://docs.llamaindex.ai/en/latest/_static/css/custom.css
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 187 [text/css]
# Saving to: ‘docs.llamaindex.ai/en/latest/_static/css/custom.css’
#
# docs.llamaindex.ai/ 100%[===================>]     187  --.-KB/s    in 0s
#
# 2024-02-11 01:28:10 (19.8 MB/s) - ‘docs.llamaindex.ai/en/latest/_static/css/custom.css’ saved [187/187]
#
# --2024-02-11 01:28:10--  https://docs.llamaindex.ai/en/latest/_static/css/algolia.css
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘docs.llamaindex.ai/en/latest/_static/css/algolia.css’
#
# docs.llamaindex.ai/     [ <=>                ]   2.10K  --.-KB/s    in 0s
#
# 2024-02-11 01:28:10 (1.00 GB/s) - ‘docs.llamaindex.ai/en/latest/_static/css/algolia.css’ saved [2155]
#
# --2024-02-11 01:28:10--  https://docs.llamaindex.ai/_/static/javascript/readthedocs-addons.js
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/javascript]
# Saving to: ‘docs.llamaindex.ai/_/static/javascript/readthedocs-addons.js’
#
# docs.llamaindex.ai/     [  <=>               ] 359.40K  1.56MB/s    in 0.2s
#
# 2024-02-11 01:28:12 (1.56 MB/s) - ‘docs.llamaindex.ai/_/static/javascript/readthedocs-addons.js’ saved [368030]
#
# --2024-02-11 01:28:12--  https://docs.llamaindex.ai/en/latest/getting_started/reading.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/getting_started/reading.html’
#
# docs.llamaindex.ai/     [ <=>                ] 225.68K  1.17MB/s    in 0.2s
#
# 2024-02-11 01:28:12 (1.17 MB/s) - ‘docs.llamaindex.ai/en/latest/getting_started/reading.html’ saved [231101]
#
# --2024-02-11 01:28:12--  https://docs.llamaindex.ai/en/latest/getting_started/starter_example.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/getting_started/starter_example.html’
#
# docs.llamaindex.ai/     [  <=>               ] 234.62K   837KB/s    in 0.3s
#
# 2024-02-11 01:28:14 (837 KB/s) - ‘docs.llamaindex.ai/en/latest/getting_started/starter_example.html’ saved [240256]
#
# --2024-02-11 01:28:14--  https://docs.llamaindex.ai/en/latest/getting_started/concepts.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/getting_started/concepts.html’
#
# docs.llamaindex.ai/     [ <=>                ] 232.57K  --.-KB/s    in 0.1s
#
# 2024-02-11 01:28:14 (1.56 MB/s) - ‘docs.llamaindex.ai/en/latest/getting_started/concepts.html’ saved [238147]
#
# --2024-02-11 01:28:14--  https://docs.llamaindex.ai/en/latest/getting_started/customization.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/getting_started/customization.html’
#
# docs.llamaindex.ai/     [ <=>                ] 239.73K  1.53MB/s    in 0.2s
#
# 2024-02-11 01:28:15 (1.53 MB/s) - ‘docs.llamaindex.ai/en/latest/getting_started/customization.html’ saved [245485]
#
# --2024-02-11 01:28:15--  https://docs.llamaindex.ai/en/latest/getting_started/discover_llamaindex.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/getting_started/discover_llamaindex.html’
#
# docs.llamaindex.ai/     [ <=>                ] 226.14K  1.23MB/s    in 0.2s
#
# 2024-02-11 01:28:16 (1.23 MB/s) - ‘docs.llamaindex.ai/en/latest/getting_started/discover_llamaindex.html’ saved [231564]
#
# --2024-02-11 01:28:16--  https://docs.llamaindex.ai/en/latest/use_cases/q_and_a/root.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/use_cases/q_and_a/root.html’
#
# docs.llamaindex.ai/     [ <=>                ] 230.31K  --.-KB/s    in 0.1s
#
# 2024-02-11 01:28:17 (1.50 MB/s) - ‘docs.llamaindex.ai/en/latest/use_cases/q_and_a/root.html’ saved [235836]
#
# --2024-02-11 01:28:17--  https://docs.llamaindex.ai/en/latest/use_cases/q_and_a/rag_cli.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/use_cases/q_and_a/rag_cli.html’
#
# docs.llamaindex.ai/     [ <=>                ] 250.30K  1.63MB/s    in 0.2s
#
# 2024-02-11 01:28:18 (1.63 MB/s) - ‘docs.llamaindex.ai/en/latest/use_cases/q_and_a/rag_cli.html’ saved [256303]
#
# --2024-02-11 01:28:18--  https://docs.llamaindex.ai/en/latest/use_cases/chatbots.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/use_cases/chatbots.html’
#
# docs.llamaindex.ai/     [ <=>                ] 223.85K  --.-KB/s    in 0.1s
#
# 2024-02-11 01:28:19 (1.56 MB/s) - ‘docs.llamaindex.ai/en/latest/use_cases/chatbots.html’ saved [229226]
#
# --2024-02-11 01:28:19--  https://docs.llamaindex.ai/en/latest/use_cases/agents.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/use_cases/agents.html’
#
# docs.llamaindex.ai/     [ <=>                ] 225.44K  --.-KB/s    in 0.1s
#
# 2024-02-11 01:28:20 (1.61 MB/s) - ‘docs.llamaindex.ai/en/latest/use_cases/agents.html’ saved [230855]
#
# --2024-02-11 01:28:20--  https://docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/agents.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/agents.html’
#
# docs.llamaindex.ai/     [ <=>                ] 235.73K  1.17MB/s    in 0.2s
#
# 2024-02-11 01:28:21 (1.17 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/agents.html’ saved [241390]
#
# --2024-02-11 01:28:21--  https://docs.llamaindex.ai/en/latest/examples/agent/openai_agent.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent.html’
#
# docs.llamaindex.ai/     [ <=>                ] 254.96K  --.-KB/s    in 0.1s
#
# 2024-02-11 01:28:22 (1.70 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent.html’ saved [261082]
#
# --2024-02-11 01:28:22--  https://docs.llamaindex.ai/en/latest/examples/agent/openai_agent_with_query_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent_with_query_engine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 229.11K  --.-KB/s    in 0.1s
#
# 2024-02-11 01:28:23 (1.50 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent_with_query_engine.html’ saved [234610]
#
# --2024-02-11 01:28:23--  https://docs.llamaindex.ai/en/latest/examples/agent/openai_agent_query_plan.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent_query_plan.html’
#
# docs.llamaindex.ai/     [ <=>                ] 252.02K  1.25MB/s    in 0.2s
#
# 2024-02-11 01:28:24 (1.25 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent_query_plan.html’ saved [258067]
#
# --2024-02-11 01:28:24--  https://docs.llamaindex.ai/en/latest/examples/agent/openai_assistant_agent.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/openai_assistant_agent.html’
#
# docs.llamaindex.ai/     [ <=>                ] 253.25K  1.46MB/s    in 0.2s
#
# 2024-02-11 01:28:26 (1.46 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/openai_assistant_agent.html’ saved [259325]
#
# --2024-02-11 01:28:26--  https://docs.llamaindex.ai/en/latest/examples/agent/openai_assistant_query_cookbook.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/openai_assistant_query_cookbook.html’
#
# docs.llamaindex.ai/     [  <=>               ] 290.79K  1.02MB/s    in 0.3s
#
# 2024-02-11 01:28:27 (1.02 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/openai_assistant_query_cookbook.html’ saved [297772]
#
# --2024-02-11 01:28:27--  https://docs.llamaindex.ai/en/latest/examples/agent/openai_forced_function_call.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/openai_forced_function_call.html’
#
# docs.llamaindex.ai/     [  <=>               ] 226.91K   892KB/s    in 0.3s
#
# 2024-02-11 01:28:27 (892 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/openai_forced_function_call.html’ saved [232358]
#
# --2024-02-11 01:28:27--  https://docs.llamaindex.ai/en/latest/examples/agent/openai_agent_parallel_function_calling.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent_parallel_function_calling.html’
#
# docs.llamaindex.ai/     [ <=>                ] 237.98K  1.25MB/s    in 0.2s
#
# 2024-02-11 01:28:28 (1.25 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent_parallel_function_calling.html’ saved [243689]
#
# --2024-02-11 01:28:28--  https://docs.llamaindex.ai/en/latest/examples/agent/openai_agent_context_retrieval.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent_context_retrieval.html’
#
# docs.llamaindex.ai/     [ <=>                ] 263.72K  1.35MB/s    in 0.2s
#
# 2024-02-11 01:28:29 (1.35 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent_context_retrieval.html’ saved [270048]
#
# --2024-02-11 01:28:29--  https://docs.llamaindex.ai/en/latest/optimizing/agentic_strategies/agentic_strategies.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/optimizing/agentic_strategies/agentic_strategies.html’
#
# docs.llamaindex.ai/     [  <=>               ] 228.41K   652KB/s    in 0.4s
#
# 2024-02-11 01:28:31 (652 KB/s) - ‘docs.llamaindex.ai/en/latest/optimizing/agentic_strategies/agentic_strategies.html’ saved [233891]
#
# --2024-02-11 01:28:31--  https://docs.llamaindex.ai/en/latest/module_guides/querying/router/root.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/querying/router/root.html’
#
# docs.llamaindex.ai/     [ <=>                ] 243.82K  1.49MB/s    in 0.2s
#
# 2024-02-11 01:28:32 (1.49 MB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/querying/router/root.html’ saved [249670]
#
# --2024-02-11 01:28:32--  https://docs.llamaindex.ai/en/latest/examples/query_engine/RouterQueryEngine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/query_engine/RouterQueryEngine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 238.18K  --.-KB/s    in 0.1s
#
# 2024-02-11 01:28:33 (1.60 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/query_engine/RouterQueryEngine.html’ saved [243893]
#
# --2024-02-11 01:28:33--  https://docs.llamaindex.ai/en/latest/examples/query_engine/RetrieverRouterQueryEngine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/query_engine/RetrieverRouterQueryEngine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 244.34K  1.36MB/s    in 0.2s
#
# 2024-02-11 01:28:34 (1.36 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/query_engine/RetrieverRouterQueryEngine.html’ saved [250205]
#
# --2024-02-11 01:28:34--  https://docs.llamaindex.ai/en/latest/examples/query_engine/SQLRouterQueryEngine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/query_engine/SQLRouterQueryEngine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 248.84K  1.23MB/s    in 0.2s
#
# 2024-02-11 01:28:35 (1.23 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/query_engine/SQLRouterQueryEngine.html’ saved [254816]
#
# --2024-02-11 01:28:35--  https://docs.llamaindex.ai/en/latest/examples/retrievers/router_retriever.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/retrievers/router_retriever.html’
#
# docs.llamaindex.ai/     [ <=>                ] 250.11K  1.38MB/s    in 0.2s
#
# 2024-02-11 01:28:36 (1.38 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/retrievers/router_retriever.html’ saved [256108]
#
# --2024-02-11 01:28:36--  https://docs.llamaindex.ai/en/latest/optimizing/advanced_retrieval/query_transformations.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/optimizing/advanced_retrieval/query_transformations.html’
#
# docs.llamaindex.ai/     [  <=>               ] 238.30K  1.04MB/s    in 0.2s
#
# 2024-02-11 01:28:36 (1.04 MB/s) - ‘docs.llamaindex.ai/en/latest/optimizing/advanced_retrieval/query_transformations.html’ saved [244019]
#
# --2024-02-11 01:28:36--  https://docs.llamaindex.ai/en/latest/examples/query_transformations/HyDEQueryTransformDemo.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/query_transformations/HyDEQueryTransformDemo.html’
#
# docs.llamaindex.ai/     [ <=>                ] 243.74K  1.35MB/s    in 0.2s
#
# 2024-02-11 01:28:37 (1.35 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/query_transformations/HyDEQueryTransformDemo.html’ saved [249590]
#
# --2024-02-11 01:28:37--  https://docs.llamaindex.ai/en/latest/examples/query_transformations/SimpleIndexDemo-multistep.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/query_transformations/SimpleIndexDemo-multistep.html’
#
# docs.llamaindex.ai/     [ <=>                ] 231.76K  --.-KB/s    in 0.1s
#
# 2024-02-11 01:28:38 (1.60 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/query_transformations/SimpleIndexDemo-multistep.html’ saved [237322]
#
# --2024-02-11 01:28:38--  https://docs.llamaindex.ai/en/latest/examples/query_engine/sub_question_query_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/query_engine/sub_question_query_engine.html’
#
# docs.llamaindex.ai/     [   <=>              ] 234.48K   522KB/s    in 0.4s
#
# 2024-02-11 01:28:40 (522 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/query_engine/sub_question_query_engine.html’ saved [240109]
#
# --2024-02-11 01:28:40--  https://docs.llamaindex.ai/en/latest/examples/agent/openai_agent_retrieval.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent_retrieval.html’
#
# docs.llamaindex.ai/     [ <=>                ] 230.46K  1.26MB/s    in 0.2s
#
# 2024-02-11 01:28:41 (1.26 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent_retrieval.html’ saved [235993]
#
# --2024-02-11 01:28:41--  https://docs.llamaindex.ai/en/latest/examples/agent/openai_agent_query_cookbook.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent_query_cookbook.html’
#
# docs.llamaindex.ai/     [  <=>               ] 288.22K  1.10MB/s    in 0.3s
#
# 2024-02-11 01:28:42 (1.10 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent_query_cookbook.html’ saved [295141]
#
# --2024-02-11 01:28:42--  https://docs.llamaindex.ai/en/latest/module_guides/deploying/agents/root.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/root.html’
#
# docs.llamaindex.ai/     [ <=>                ] 233.17K  1.39MB/s    in 0.2s
#
# 2024-02-11 01:28:43 (1.39 MB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/root.html’ saved [238762]
#
# --2024-02-11 01:28:43--  https://docs.llamaindex.ai/en/latest/module_guides/deploying/agents/usage_pattern.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/usage_pattern.html’
#
# docs.llamaindex.ai/     [  <=>               ] 249.51K   601KB/s    in 0.4s
#
# 2024-02-11 01:28:44 (601 KB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/usage_pattern.html’ saved [255500]
#
# --2024-02-11 01:28:44--  https://docs.llamaindex.ai/en/latest/module_guides/deploying/agents/modules.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/modules.html’
#
# docs.llamaindex.ai/     [ <=>                ] 231.75K  --.-KB/s    in 0.1s
#
# 2024-02-11 01:28:45 (1.55 MB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/modules.html’ saved [237313]
#
# --2024-02-11 01:28:45--  https://docs.llamaindex.ai/en/latest/examples/query_engine/recursive_retriever_agents.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/query_engine/recursive_retriever_agents.html’
#
# docs.llamaindex.ai/     [  <=>               ] 243.24K  1.11MB/s    in 0.2s
#
# 2024-02-11 01:28:46 (1.11 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/query_engine/recursive_retriever_agents.html’ saved [249081]
#
# --2024-02-11 01:28:46--  https://docs.llamaindex.ai/en/latest/examples/agent/multi_document_agents.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/multi_document_agents.html’
#
# docs.llamaindex.ai/     [   <=>              ] 280.30K   564KB/s    in 0.5s
#
# 2024-02-11 01:28:48 (564 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/multi_document_agents.html’ saved [287027]
#
# --2024-02-11 01:28:48--  https://docs.llamaindex.ai/en/latest/examples/agent/agent_builder.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/agent_builder.html’
#
# docs.llamaindex.ai/     [ <=>                ] 249.68K  1.32MB/s    in 0.2s
#
# 2024-02-11 01:28:49 (1.32 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/agent_builder.html’ saved [255674]
#
# --2024-02-11 01:28:49--  https://docs.llamaindex.ai/en/latest/examples/agent/openai_retrieval_benchmark.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/openai_retrieval_benchmark.html’
#
# docs.llamaindex.ai/     [  <=>               ] 259.81K  1.24MB/s    in 0.2s
#
# 2024-02-11 01:28:50 (1.24 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/openai_retrieval_benchmark.html’ saved [266049]
#
# --2024-02-11 01:28:50--  https://docs.llamaindex.ai/en/latest/examples/agent/react_agent.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/react_agent.html’
#
# docs.llamaindex.ai/     [ <=>                ] 239.19K  --.-KB/s    in 0.1s
#
# 2024-02-11 01:28:51 (1.88 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/react_agent.html’ saved [244928]
#
# --2024-02-11 01:28:51--  https://docs.llamaindex.ai/en/latest/examples/agent/react_agent_with_query_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/react_agent_with_query_engine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 250.70K  1.43MB/s    in 0.2s
#
# 2024-02-11 01:28:52 (1.43 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/react_agent_with_query_engine.html’ saved [256713]
#
# --2024-02-11 01:28:52--  https://docs.llamaindex.ai/en/latest/examples/agent/custom_agent.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/custom_agent.html’
#
# docs.llamaindex.ai/     [  <=>               ] 275.59K  1.04MB/s    in 0.3s
#
# 2024-02-11 01:28:52 (1.04 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/custom_agent.html’ saved [282209]
#
# --2024-02-11 01:28:52--  https://docs.llamaindex.ai/en/latest/examples/agent/agent_runner/query_pipeline_agent.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/agent_runner/query_pipeline_agent.html’
#
# docs.llamaindex.ai/     [  <=>               ] 301.13K  1.25MB/s    in 0.2s
#
# 2024-02-11 01:28:53 (1.25 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/agent_runner/query_pipeline_agent.html’ saved [308358]
#
# --2024-02-11 01:28:53--  https://docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner.html’
#
# docs.llamaindex.ai/     [ <=>                ] 255.63K  1.39MB/s    in 0.2s
#
# 2024-02-11 01:28:54 (1.39 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner.html’ saved [261764]
#
# --2024-02-11 01:28:54--  https://docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner_rag.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner_rag.html’
#
# docs.llamaindex.ai/     [ <=>                ] 256.91K  1.45MB/s    in 0.2s
#
# 2024-02-11 01:28:55 (1.45 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner_rag.html’ saved [263080]
#
# --2024-02-11 01:28:55--  https://docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner_rag_controllable.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner_rag_controllable.html’
#
# docs.llamaindex.ai/     [   <=>              ] 275.81K   633KB/s    in 0.4s
#
# 2024-02-11 01:28:57 (633 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner_rag_controllable.html’ saved [282430]
#
# --2024-02-11 01:28:57--  https://docs.llamaindex.ai/en/latest/module_guides/deploying/agents/tools/root.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/tools/root.html’
#
# docs.llamaindex.ai/     [ <=>                ] 234.19K  --.-KB/s    in 0.1s
#
# 2024-02-11 01:28:58 (1.67 MB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/tools/root.html’ saved [239809]
#
# --2024-02-11 01:28:58--  https://docs.llamaindex.ai/en/latest/module_guides/deploying/agents/tools/usage_pattern.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/tools/usage_pattern.html’
#
# docs.llamaindex.ai/     [ <=>                ] 234.67K  1.43MB/s    in 0.2s
#
# 2024-02-11 01:28:59 (1.43 MB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/tools/usage_pattern.html’ saved [240300]
#
# --2024-02-11 01:28:59--  https://docs.llamaindex.ai/en/latest/module_guides/deploying/agents/tools/llamahub_tools_guide.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/tools/llamahub_tools_guide.html’
#
# docs.llamaindex.ai/     [  <=>               ] 236.01K  1.08MB/s    in 0.2s
#
# 2024-02-11 01:29:00 (1.08 MB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/tools/llamahub_tools_guide.html’ saved [241674]
#
# --2024-02-11 01:29:00--  https://docs.llamaindex.ai/en/latest/module_guides/deploying/agents/agent_runner.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/agent_runner.html’
#
# docs.llamaindex.ai/     [   <=>              ] 235.01K   340KB/s    in 0.7s
#
# 2024-02-11 01:29:01 (340 KB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/agent_runner.html’ saved [240651]
#
# --2024-02-11 01:29:01--  https://docs.llamaindex.ai/en/latest/use_cases/extraction.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/use_cases/extraction.html’
#
# docs.llamaindex.ai/     [  <=>               ] 225.46K  1.04MB/s    in 0.2s
#
# 2024-02-11 01:29:02 (1.04 MB/s) - ‘docs.llamaindex.ai/en/latest/use_cases/extraction.html’ saved [230868]
#
# --2024-02-11 01:29:02--  https://docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/structured_outputs.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/structured_outputs.html’
#
# docs.llamaindex.ai/     [  <=>               ] 229.48K   800KB/s    in 0.3s
#
# 2024-02-11 01:29:03 (800 KB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/structured_outputs.html’ saved [234985]
#
# --2024-02-11 01:29:04--  https://docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/pydantic_program.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/pydantic_program.html’
#
# docs.llamaindex.ai/     [ <=>                ] 229.27K  1.36MB/s    in 0.2s
#
# 2024-02-11 01:29:05 (1.36 MB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/pydantic_program.html’ saved [234769]
#
# --2024-02-11 01:29:05--  https://docs.llamaindex.ai/en/latest/examples/output_parsing/llm_program.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/output_parsing/llm_program.html’
#
# docs.llamaindex.ai/     [  <=>               ] 235.81K   980KB/s    in 0.2s
#
# 2024-02-11 01:29:06 (980 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/output_parsing/llm_program.html’ saved [241473]
#
# --2024-02-11 01:29:06--  https://docs.llamaindex.ai/en/latest/examples/output_parsing/openai_pydantic_program.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/output_parsing/openai_pydantic_program.html’
#
# docs.llamaindex.ai/     [  <=>               ] 245.72K  1.06MB/s    in 0.2s
#
# 2024-02-11 01:29:07 (1.06 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/output_parsing/openai_pydantic_program.html’ saved [251620]
#
# --2024-02-11 01:29:07--  https://docs.llamaindex.ai/en/latest/examples/output_parsing/guidance_pydantic_program.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/output_parsing/guidance_pydantic_program.html’
#
# docs.llamaindex.ai/     [ <=>                ] 231.76K  --.-KB/s    in 0.1s
#
# 2024-02-11 01:29:07 (1.69 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/output_parsing/guidance_pydantic_program.html’ saved [237325]
#
# --2024-02-11 01:29:07--  https://docs.llamaindex.ai/en/latest/examples/output_parsing/guidance_sub_question.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/output_parsing/guidance_sub_question.html’
#
# docs.llamaindex.ai/     [  <=>               ] 237.66K  1.10MB/s    in 0.2s
#
# 2024-02-11 01:29:08 (1.10 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/output_parsing/guidance_sub_question.html’ saved [243367]
#
# --2024-02-11 01:29:08--  https://docs.llamaindex.ai/en/latest/examples/output_parsing/df_program.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/output_parsing/df_program.html’
#
# docs.llamaindex.ai/     [ <=>                ] 242.89K  1.53MB/s    in 0.2s
#
# 2024-02-11 01:29:10 (1.53 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/output_parsing/df_program.html’ saved [248719]
#
# --2024-02-11 01:29:10--  https://docs.llamaindex.ai/en/latest/examples/output_parsing/evaporate_program.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/output_parsing/evaporate_program.html’
#
# docs.llamaindex.ai/     [  <=>               ] 273.73K   963KB/s    in 0.3s
#
# 2024-02-11 01:29:10 (963 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/output_parsing/evaporate_program.html’ saved [280300]
#
# --2024-02-11 01:29:10--  https://docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/query_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/query_engine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 233.21K  1.36MB/s    in 0.2s
#
# 2024-02-11 01:29:11 (1.36 MB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/query_engine.html’ saved [238802]
#
# --2024-02-11 01:29:11--  https://docs.llamaindex.ai/en/latest/examples/query_engine/pydantic_query_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/query_engine/pydantic_query_engine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 239.58K  1.24MB/s    in 0.2s
#
# 2024-02-11 01:29:11 (1.24 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/query_engine/pydantic_query_engine.html’ saved [245331]
#
# --2024-02-11 01:29:11--  https://docs.llamaindex.ai/en/latest/examples/response_synthesizers/pydantic_tree_summarize.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/response_synthesizers/pydantic_tree_summarize.html’
#
# docs.llamaindex.ai/     [  <=>               ] 228.83K   911KB/s    in 0.3s
#
# 2024-02-11 01:29:12 (911 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/response_synthesizers/pydantic_tree_summarize.html’ saved [234326]
#
# --2024-02-11 01:29:12--  https://docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/output_parser.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/output_parser.html’
#
# docs.llamaindex.ai/     [ <=>                ] 238.64K  --.-KB/s    in 0.1s
#
# 2024-02-11 01:29:13 (1.79 MB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/output_parser.html’ saved [244363]
#
# --2024-02-11 01:29:13--  https://docs.llamaindex.ai/en/latest/examples/output_parsing/GuardrailsDemo.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/output_parsing/GuardrailsDemo.html’
#
# docs.llamaindex.ai/     [  <=>               ] 271.04K   852KB/s    in 0.3s
#
# 2024-02-11 01:29:14 (852 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/output_parsing/GuardrailsDemo.html’ saved [277541]
#
# --2024-02-11 01:29:14--  https://docs.llamaindex.ai/en/latest/examples/output_parsing/LangchainOutputParserDemo.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/output_parsing/LangchainOutputParserDemo.html’
#
# docs.llamaindex.ai/     [ <=>                ] 230.85K  --.-KB/s    in 0.1s
#
# 2024-02-11 01:29:15 (1.65 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/output_parsing/LangchainOutputParserDemo.html’ saved [236390]
#
# --2024-02-11 01:29:15--  https://docs.llamaindex.ai/en/latest/examples/llm/llama_api.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/llm/llama_api.html’
#
# docs.llamaindex.ai/     [ <=>                ] 233.70K  1.23MB/s    in 0.2s
#
# 2024-02-11 01:29:16 (1.23 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/llm/llama_api.html’ saved [239312]
#
# --2024-02-11 01:29:16--  https://docs.llamaindex.ai/en/latest/examples/usecases/email_data_extraction.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/usecases/email_data_extraction.html’
#
# docs.llamaindex.ai/     [ <=>                ] 260.08K  1.43MB/s    in 0.2s
#
# 2024-02-11 01:29:17 (1.43 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/usecases/email_data_extraction.html’ saved [266326]
#
# --2024-02-11 01:29:17--  https://docs.llamaindex.ai/en/latest/use_cases/multimodal.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/use_cases/multimodal.html’
#
# docs.llamaindex.ai/     [  <=>               ] 231.14K  1.06MB/s    in 0.2s
#
# 2024-02-11 01:29:18 (1.06 MB/s) - ‘docs.llamaindex.ai/en/latest/use_cases/multimodal.html’ saved [236687]
#
# --2024-02-11 01:29:18--  https://docs.llamaindex.ai/en/latest/examples/multi_modal/gpt4v_multi_modal_retrieval.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/multi_modal/gpt4v_multi_modal_retrieval.html’
#
# docs.llamaindex.ai/     [  <=>               ] 266.98K  1.07MB/s    in 0.2s
#
# 2024-02-11 01:29:19 (1.07 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/multi_modal/gpt4v_multi_modal_retrieval.html’ saved [273391]
#
# --2024-02-11 01:29:19--  https://docs.llamaindex.ai/en/latest/examples/multi_modal/multi_modal_retrieval.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/multi_modal/multi_modal_retrieval.html’
#
# docs.llamaindex.ai/     [  <=>               ] 261.57K   975KB/s    in 0.3s
#
# 2024-02-11 01:29:19 (975 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/multi_modal/multi_modal_retrieval.html’ saved [267849]
#
# --2024-02-11 01:29:19--  https://docs.llamaindex.ai/en/latest/examples/multi_modal/image_to_image_retrieval.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/multi_modal/image_to_image_retrieval.html’
#
# docs.llamaindex.ai/     [  <=>               ] 248.22K  1.13MB/s    in 0.2s
#
# 2024-02-11 01:29:20 (1.13 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/multi_modal/image_to_image_retrieval.html’ saved [254173]
#
# --2024-02-11 01:29:20--  https://docs.llamaindex.ai/en/latest/examples/multi_modal/structured_image_retrieval.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/multi_modal/structured_image_retrieval.html’
#
# docs.llamaindex.ai/     [  <=>               ] 256.50K  1.11MB/s    in 0.2s
#
# 2024-02-11 01:29:21 (1.11 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/multi_modal/structured_image_retrieval.html’ saved [262652]
#
# --2024-02-11 01:29:21--  https://docs.llamaindex.ai/en/latest/examples/multi_modal/ChromaMultiModalDemo.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/multi_modal/ChromaMultiModalDemo.html’
#
# docs.llamaindex.ai/     [  <=>               ] 245.14K  1.05MB/s    in 0.2s
#
# 2024-02-11 01:29:21 (1.05 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/multi_modal/ChromaMultiModalDemo.html’ saved [251023]
#
# --2024-02-11 01:29:22--  https://docs.llamaindex.ai/en/latest/examples/multi_modal/multi_modal_pdf_tables.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/multi_modal/multi_modal_pdf_tables.html’
#
# docs.llamaindex.ai/     [  <=>               ] 327.19K  1.41MB/s    in 0.2s
#
# 2024-02-11 01:29:23 (1.41 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/multi_modal/multi_modal_pdf_tables.html’ saved [335044]
#
# --2024-02-11 01:29:23--  https://docs.llamaindex.ai/en/latest/examples/multi_modal/gemini.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/multi_modal/gemini.html’
#
# docs.llamaindex.ai/     [ <=>                ] 259.68K  1.53MB/s    in 0.2s
#
# 2024-02-11 01:29:23 (1.53 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/multi_modal/gemini.html’ saved [265908]
#
# --2024-02-11 01:29:23--  https://docs.llamaindex.ai/en/latest/examples/multi_modal/ollama_cookbook.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/multi_modal/ollama_cookbook.html’
#
# docs.llamaindex.ai/     [  <=>               ] 259.29K  1.08MB/s    in 0.2s
#
# 2024-02-11 01:29:24 (1.08 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/multi_modal/ollama_cookbook.html’ saved [265512]
#
# --2024-02-11 01:29:24--  https://docs.llamaindex.ai/en/latest/examples/multi_modal/multi_modal_pydantic.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/multi_modal/multi_modal_pydantic.html’
#
# docs.llamaindex.ai/     [  <=>               ] 262.11K   985KB/s    in 0.3s
#
# 2024-02-11 01:29:25 (985 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/multi_modal/multi_modal_pydantic.html’ saved [268404]
#
# --2024-02-11 01:29:25--  https://docs.llamaindex.ai/en/latest/examples/multi_modal/llava_multi_modal_tesla_10q.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/multi_modal/llava_multi_modal_tesla_10q.html’
#
# docs.llamaindex.ai/     [  <=>               ] 252.70K  1.22MB/s    in 0.2s
#
# 2024-02-11 01:29:26 (1.22 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/multi_modal/llava_multi_modal_tesla_10q.html’ saved [258767]
#
# --2024-02-11 01:29:26--  https://docs.llamaindex.ai/en/latest/examples/multi_modal/mm_agent.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# ...
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/low_level/vector_store.html’
#
# docs.llamaindex.ai/     [   <=>              ] 276.83K   662KB/s    in 0.4s
#
# 2024-02-11 01:32:14 (662 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/low_level/vector_store.html’ saved [283471]
#
# --2024-02-11 01:32:14--  https://docs.llamaindex.ai/en/latest/examples/low_level/response_synthesis.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/low_level/response_synthesis.html’
#
# docs.llamaindex.ai/     [   <=>              ] 294.55K   592KB/s    in 0.5s
#
# 2024-02-11 01:32:15 (592 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/low_level/response_synthesis.html’ saved [301620]
#
# --2024-02-11 01:32:15--  https://docs.llamaindex.ai/en/latest/examples/low_level/evaluation.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/low_level/evaluation.html’
#
# docs.llamaindex.ai/     [  <=>               ] 274.75K   795KB/s    in 0.3s
#
# 2024-02-11 01:32:16 (795 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/low_level/evaluation.html’ saved [281344]
#
# --2024-02-11 01:32:16--  https://docs.llamaindex.ai/en/latest/examples/vector_stores/qdrant_hybrid.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/vector_stores/qdrant_hybrid.html’
#
# docs.llamaindex.ai/     [   <=>              ] 266.73K   647KB/s    in 0.4s
#
# 2024-02-11 01:32:17 (647 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/vector_stores/qdrant_hybrid.html’ saved [273131]
#
# --2024-02-11 01:32:17--  https://docs.llamaindex.ai/en/latest/examples/low_level/router.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/low_level/router.html’
#
# docs.llamaindex.ai/     [  <=>               ] 269.34K   867KB/s    in 0.3s
#
# 2024-02-11 01:32:18 (867 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/low_level/router.html’ saved [275800]
#
# --2024-02-11 01:32:18--  https://docs.llamaindex.ai/en/latest/examples/low_level/fusion_retriever.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/low_level/fusion_retriever.html’
#
# docs.llamaindex.ai/     [  <=>               ] 251.76K   801KB/s    in 0.3s
#
# 2024-02-11 01:32:19 (801 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/low_level/fusion_retriever.html’ saved [257802]
#
# --2024-02-11 01:32:19--  https://docs.llamaindex.ai/en/latest/examples/pipeline/query_pipeline_sql.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/pipeline/query_pipeline_sql.html’
#
# docs.llamaindex.ai/     [   <=>              ] 308.28K   563KB/s    in 0.5s
#
# 2024-02-11 01:32:20 (563 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/pipeline/query_pipeline_sql.html’ saved [315677]
#
# --2024-02-11 01:32:20--  https://docs.llamaindex.ai/en/latest/examples/pipeline/query_pipeline_pandas.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/pipeline/query_pipeline_pandas.html’
#
# docs.llamaindex.ai/     [  <=>               ] 233.96K   621KB/s    in 0.4s
#
# 2024-02-11 01:32:21 (621 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/pipeline/query_pipeline_pandas.html’ saved [239573]
#
# --2024-02-11 01:32:21--  https://docs.llamaindex.ai/en/latest/module_guides/models/models.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/models/models.html’
#
# docs.llamaindex.ai/     [  <=>               ] 223.60K   702KB/s    in 0.3s
#
# 2024-02-11 01:32:22 (702 KB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/models/models.html’ saved [228970]
#
# --2024-02-11 01:32:22--  https://docs.llamaindex.ai/en/latest/module_guides/models/llms.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/models/llms.html’
#
# docs.llamaindex.ai/     [  <=>               ] 241.81K   722KB/s    in 0.3s
#
# 2024-02-11 01:32:24 (722 KB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/models/llms.html’ saved [247611]
#
# --2024-02-11 01:32:24--  https://docs.llamaindex.ai/en/latest/module_guides/models/llms/usage_standalone.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/models/llms/usage_standalone.html’
#
# docs.llamaindex.ai/     [  <=>               ] 230.16K   607KB/s    in 0.4s
#
# 2024-02-11 01:32:25 (607 KB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/models/llms/usage_standalone.html’ saved [235688]
#
# --2024-02-11 01:32:25--  https://docs.llamaindex.ai/en/latest/module_guides/models/llms/usage_custom.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/models/llms/usage_custom.html’
#
# docs.llamaindex.ai/     [  <=>               ] 253.14K   633KB/s    in 0.4s
#
# 2024-02-11 01:32:26 (633 KB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/models/llms/usage_custom.html’ saved [259220]
#
# --2024-02-11 01:32:26--  https://docs.llamaindex.ai/en/latest/module_guides/models/llms/modules.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/models/llms/modules.html’
#
# docs.llamaindex.ai/     [   <=>              ] 242.56K   579KB/s    in 0.4s
#
# 2024-02-11 01:32:27 (579 KB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/models/llms/modules.html’ saved [248379]
#
# --2024-02-11 01:32:27--  https://docs.llamaindex.ai/en/latest/examples/llm/ai21.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/llm/ai21.html’
#
# docs.llamaindex.ai/     [  <=>               ] 245.62K   648KB/s    in 0.4s
#
# 2024-02-11 01:32:28 (648 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/llm/ai21.html’ saved [251512]
#
# --2024-02-11 01:32:28--  https://docs.llamaindex.ai/en/latest/examples/llm/anthropic.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/llm/anthropic.html’
#
# docs.llamaindex.ai/     [  <=>               ] 238.40K   683KB/s    in 0.3s
#
# 2024-02-11 01:32:29 (683 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/llm/anthropic.html’ saved [244122]
#
# --2024-02-11 01:32:29--  https://docs.llamaindex.ai/en/latest/examples/llm/anyscale.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/llm/anyscale.html’
#
# docs.llamaindex.ai/     [  <=>               ] 229.02K   631KB/s    in 0.4s
#
# 2024-02-11 01:32:31 (631 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/llm/anyscale.html’ saved [234515]
#
# --2024-02-11 01:32:31--  https://docs.llamaindex.ai/en/latest/examples/llm/bedrock.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/llm/bedrock.html’
#
# docs.llamaindex.ai/     [  <=>               ] 243.26K   622KB/s    in 0.4s
#
# 2024-02-11 01:32:32 (622 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/llm/bedrock.html’ saved [249099]
#
# --2024-02-11 01:32:32--  https://docs.llamaindex.ai/en/latest/examples/llm/clarifai.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/llm/clarifai.html’
#
# docs.llamaindex.ai/     [  <=>               ] 228.57K   618KB/s    in 0.4s
#
# 2024-02-11 01:32:33 (618 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/llm/clarifai.html’ saved [234057]
#
# --2024-02-11 01:32:33--  https://docs.llamaindex.ai/en/latest/examples/llm/cohere.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/llm/cohere.html’
#
# docs.llamaindex.ai/     [  <=>               ] 262.68K   757KB/s    in 0.3s
#
# 2024-02-11 01:32:34 (757 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/llm/cohere.html’ saved [268983]
#
# --2024-02-11 01:32:34--  https://docs.llamaindex.ai/en/latest/examples/llm/everlyai.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/llm/everlyai.html’
#
# docs.llamaindex.ai/     [  <=>               ] 226.65K   635KB/s    in 0.4s
#
# 2024-02-11 01:32:35 (635 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/llm/everlyai.html’ saved [232089]
#
# --2024-02-11 01:32:35--  https://docs.llamaindex.ai/en/latest/examples/llm/gradient_base_model.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/llm/gradient_base_model.html’
#
# docs.llamaindex.ai/     [  <=>               ] 226.47K   698KB/s    in 0.3s
#
# 2024-02-11 01:32:36 (698 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/llm/gradient_base_model.html’ saved [231905]
#
# --2024-02-11 01:32:36--  https://docs.llamaindex.ai/en/latest/examples/llm/gradient_model_adapter.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/llm/gradient_model_adapter.html’
#
# docs.llamaindex.ai/     [  <=>               ] 226.27K   684KB/s    in 0.3s
#
# 2024-02-11 01:32:37 (684 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/llm/gradient_model_adapter.html’ saved [231705]
#
# --2024-02-11 01:32:37--  https://docs.llamaindex.ai/en/latest/examples/customization/llms/SimpleIndexDemo-Huggingface_camel.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/customization/llms/SimpleIndexDemo-Huggingface_camel.html’
#
# docs.llamaindex.ai/     [  <=>               ] 238.59K   690KB/s    in 0.3s
#
# 2024-02-11 01:32:38 (690 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/customization/llms/SimpleIndexDemo-Huggingface_camel.html’ saved [244316]
#
# --2024-02-11 01:32:38--  https://docs.llamaindex.ai/en/latest/examples/customization/llms/SimpleIndexDemo-Huggingface_stablelm.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/customization/llms/SimpleIndexDemo-Huggingface_stablelm.html’
#
# docs.llamaindex.ai/     [  <=>               ] 240.18K   688KB/s    in 0.3s
#
# 2024-02-11 01:32:39 (688 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/customization/llms/SimpleIndexDemo-Huggingface_stablelm.html’ saved [245947]
#
# --2024-02-11 01:32:39--  https://docs.llamaindex.ai/en/latest/examples/vector_stores/SimpleIndexDemoLlama-Local.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/vector_stores/SimpleIndexDemoLlama-Local.html’
#
# docs.llamaindex.ai/     [   <=>              ] 319.89K   621KB/s    in 0.5s
#
# 2024-02-11 01:32:40 (621 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/vector_stores/SimpleIndexDemoLlama-Local.html’ saved [327569]
#
# --2024-02-11 01:32:40--  https://docs.llamaindex.ai/en/latest/examples/llm/konko.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/llm/konko.html’
#
# docs.llamaindex.ai/     [  <=>               ] 242.15K   595KB/s    in 0.4s
#
# 2024-02-11 01:32:42 (595 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/llm/konko.html’ saved [247964]
#
# --2024-02-11 01:32:42--  https://docs.llamaindex.ai/en/latest/examples/llm/langchain.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/llm/langchain.html’
#
# docs.llamaindex.ai/     [  <=>               ] 219.56K   688KB/s    in 0.3s
#
# 2024-02-11 01:32:43 (688 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/llm/langchain.html’ saved [224833]
#
# --2024-02-11 01:32:43--  https://docs.llamaindex.ai/en/latest/examples/llm/litellm.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/llm/litellm.html’
#
# docs.llamaindex.ai/     [  <=>               ] 234.66K   688KB/s    in 0.3s
#
# 2024-02-11 01:32:44 (688 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/llm/litellm.html’ saved [240294]
#
# --2024-02-11 01:32:44--  https://docs.llamaindex.ai/en/latest/examples/llm/llama_2_llama_cpp.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/llm/llama_2_llama_cpp.html’
#
# docs.llamaindex.ai/     [  <=>               ] 243.53K   635KB/s    in 0.4s
#
# 2024-02-11 01:32:45 (635 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/llm/llama_2_llama_cpp.html’ saved [249372]
#
# --2024-02-11 01:32:45--  https://docs.llamaindex.ai/en/latest/examples/llm/localai.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/llm/localai.html’
#
# docs.llamaindex.ai/     [  <=>               ] 229.75K   621KB/s    in 0.4s
#
# 2024-02-11 01:32:46 (621 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/llm/localai.html’ saved [235264]
#
# --2024-02-11 01:32:46--  https://docs.llamaindex.ai/en/latest/examples/llm/mistralai.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/llm/mistralai.html’
#
# docs.llamaindex.ai/     [  <=>               ] 249.02K   693KB/s    in 0.4s
#
# 2024-02-11 01:32:47 (693 KB/s) - ‘docs.llamaindex.ai/en/latest/examples/llm/mistralai.html’ saved [254996]
#
# --2024-02-11 01:32:47--  https://docs.llamaindex.ai/en/latest/examples/llm/monsterapi.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/llm/monsterapi.html’
#
#           docs.llam     [<=>                 ]       0  --.-KB/s

# %%
from llama_hub.file.unstructured.base import UnstructuredReader
from llama_index.llms.openai import OpenAI
from llama_index.service_context import ServiceContext
from pathlib import Path

# %%
reader = UnstructuredReader()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/kosisochukwuasuzu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/kosisochukwuasuzu/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
all_files_gen = Path("./docs.llamaindex.ai/").rglob("*")
all_files = [f.resolve() for f in all_files_gen]

# %%
len(all_files)
# Out:
# 322

# %%
suffixes = set([file.suffix for file in all_files])

# %%
suffixes
# Out:
# {'', '.css', '.html', '.js'}

# %%
all_html_files = [file for file in all_files if file.suffix.lower() == ".html"]

# %%
len(all_html_files)
# Out:
# 227

# %%
from llama_index.schema import Document

doc_limit = 100

# %%
docs = []
for idx in range(doc_limit):
    f = all_html_files[idx]
    print(f"Idx {idx}/{len(all_html_files)}")
    loaded_doc = reader.load_data(file=f, split_documents=True)
    start_idx = 72
    loaded_doc = Document(
        text= "\n\n".join([d.get_content() for d in loaded_doc[72:]]),
        metadata={"path": str(f)}
    )
    print(loaded_doc.metadata["path"])
    docs.append(loaded_doc)
# Out:
# Idx 0/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/index.html
# Idx 1/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/genindex.html
# Idx 2/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/search.html
# Idx 3/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/understanding.html
# Idx 4/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/using_llms/using_llms.html
# Idx 5/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/using_llms/privacy.html
# Idx 6/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/loading/llamahub.html
# Idx 7/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/loading/loading.html
# Idx 8/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/evaluating/evaluating.html
# Idx 9/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/evaluating/cost_analysis/root.html
# Idx 10/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/evaluating/cost_analysis/usage_pattern.html
# Idx 11/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/storing/storing.html
# Idx 12/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/tracing_and_debugging/tracing_and_debugging.html
# Idx 13/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/indexing/indexing.html
# Idx 14/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/querying/querying.html
# Idx 15/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/apps.html
# Idx 16/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/q_and_a.html
# Idx 17/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/graphs.html
# Idx 18/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/structured_data.html
# Idx 19/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/agents.html
# Idx 20/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/putting_it_all_together.html
# Idx 21/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/q_and_a/terms_definitions_tutorial.html
# Idx 22/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/q_and_a/unified_query.html
# Idx 23/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/structured_data/Airbyte_demo.html
# Idx 24/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/chatbots/building_a_chatbot.html
# Idx 25/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/apps/fullstack_app_guide.html
# Idx 26/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/apps/fullstack_with_delphic.html
# Idx 27/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/vector_stores/chroma_auto_retriever.html
# Idx 28/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/vector_stores/SimpleIndexDemoLlama-Local.html
# Idx 29/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/vector_stores/WeaviateIndexDemo-Hybrid.html
# Idx 30/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/vector_stores/PineconeIndexDemo-Hybrid.html
# Idx 31/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/vector_stores/qdrant_hybrid.html
# Idx 32/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/pipeline/query_pipeline_pandas.html
# Idx 33/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/pipeline/query_pipeline_sql.html
# Idx 34/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/retrievers/reciprocal_rerank_fusion.html
# Idx 35/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/retrievers/deep_memory.html
# Idx 36/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/retrievers/router_retriever.html
# Idx 37/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/retrievers/bm25_retriever.html
# Idx 38/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/retrievers/auto_vs_recursive_retriever.html
# Idx 39/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/retrievers/composable_retrievers.html
# Idx 40/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/ingestion/async_ingestion_pipeline.html
# Idx 41/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/ingestion/parallel_execution_ingestion_pipeline.html
# Idx 42/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/ingestion/document_management_pipeline.html
# Idx 43/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/ingestion/ingestion_gdrive.html
# Idx 44/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/ingestion/advanced_ingestion_pipeline.html
# Idx 45/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/ingestion/redis_ingestion_pipeline.html
# Idx 46/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/llama_2_llama_cpp.html
# Idx 47/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/localai.html
# Idx 48/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/bedrock.html
# Idx 49/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/gradient_base_model.html
# Idx 50/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/langchain.html
# Idx 51/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/litellm.html
# Idx 52/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/anyscale.html
# Idx 53/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/cohere.html
# Idx 54/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/monsterapi.html
# Idx 55/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/everlyai.html
# Idx 56/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/gradient_model_adapter.html
# Idx 57/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/ai21.html
# Idx 58/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/llama_api.html
# Idx 59/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/clarifai.html
# Idx 60/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/mistralai.html
# Idx 61/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/konko.html
# Idx 62/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/llm/anthropic.html
# Idx 63/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/customization/llms/SimpleIndexDemo-Huggingface_stablelm.html
# Idx 64/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/customization/llms/SimpleIndexDemo-Huggingface_camel.html
# Idx 65/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/metadata_extraction/MetadataExtraction_LLMSurvey.html
# Idx 66/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/metadata_extraction/MarvinMetadataExtractorDemo.html
# Idx 67/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/metadata_extraction/MetadataExtractionSEC.html
# Idx 68/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/metadata_extraction/EntityExtractionClimate.html
# Idx 69/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/metadata_extraction/PydanticExtractor.html
# Idx 70/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/multi_tenancy/multi_tenancy_rag.html
# Idx 71/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/output_parsing/LangchainOutputParserDemo.html
# Idx 72/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/output_parsing/llm_program.html
# Idx 73/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/output_parsing/GuardrailsDemo.html
# Idx 74/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/output_parsing/openai_pydantic_program.html
# Idx 75/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/output_parsing/df_program.html
# Idx 76/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/output_parsing/guidance_pydantic_program.html
# Idx 77/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/output_parsing/guidance_sub_question.html
# Idx 78/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/output_parsing/evaporate_program.html
# Idx 79/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/openai_agent.html
# Idx 80/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/openai_agent_parallel_function_calling.html
# Idx 81/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/multi_document_agents.html
# Idx 82/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/openai_agent_query_plan.html
# Idx 83/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/custom_agent.html
# Idx 84/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/openai_agent_retrieval.html
# Idx 85/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/openai_retrieval_benchmark.html
# Idx 86/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/openai_forced_function_call.html
# Idx 87/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/openai_agent_context_retrieval.html
# Idx 88/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/openai_agent_query_cookbook.html
# Idx 89/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/react_agent.html
# Idx 90/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/agent_builder.html
# Idx 91/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/openai_assistant_query_cookbook.html
# Idx 92/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/openai_agent_with_query_engine.html
# Idx 93/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/react_agent_with_query_engine.html
# Idx 94/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/openai_assistant_agent.html
# Idx 95/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner.html
# Idx 96/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner_rag_controllable.html
# Idx 97/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner_rag.html
# Idx 98/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/agent/agent_runner/query_pipeline_agent.html
# Idx 99/227
# /Users/kosisochukwuasuzu/Developer/ai-startups/test-demos/pdfchat/src/llamaindex/qa/multidocagentqa/docs.llamaindex.ai/en/latest/examples/finetuning/openai_fine_tuning_functions.html

# %%
llm = OpenAI(model="mistralai/Mixtral-8x7B-Instruct-v0.1", temperature=0.0)
service_context = ServiceContext.from_defaults(llm=llm)

# %%
from llama_index.indices.vector_store import VectorStoreIndex
from llama_index.indices.list.base import SummaryIndex

# %%
import nest_asyncio

nest_asyncio.apply()

# %% [markdown]
# #### Building document agent for each html document
# This means we will have ~227 agents. We define two query engines on each document, we have the semantic search engine the summaraization engine, these are then passed to the agent as tools, we would be using openais function calling capability to acheive this

# %%
from llama_index.agent.openai.base import OpenAIAgent
from llama_index.indices.loading import load_index_from_storage
from llama_index.storage import StorageContext
from llama_index.tools.query_engine import QueryEngineTool
from llama_index.tools.types import ToolMetadata
from llama_index.node_parser import SentenceSplitter
import os
from tqdm import tqdm
import pickle

# %%
from textwrap import dedent

# %%
async def build_agent_per_doc(nodes, file_base):
    print(file_base)
    vi_out_path = f"./data/llamaindex_docs/{file_base}" # output path for vector index
    summary_out_path = f"./data/llamaindex_docs/{file_base}_summary.pkl" # output file for summary index
    
    if not os.path.exists(vi_out_path):
        Path("./data/llamaindex_docs/").mkdir(parents=True, exist_ok=True)
        vector_index = VectorStoreIndex(nodes, service_context=service_context)
        vector_index.storage_context.persist(persist_dir=vi_out_path)
        
    else:
        vector_index = load_index_from_storage(StorageContext.from_defaults(persist_dir=vi_out_path),
                                               service_context=service_context)
    
    # build the summary index
    summary_index = SummaryIndex(nodes, service_context=service_context)
    
    vector_query_engine = vector_index.as_query_engine()
    summary_query_engine = summary_index.as_query_engine(response_mode="tree_summarize")
    
    if not os.path.exists(summary_out_path):
        Path(summary_out_path).parent.mkdir(parents=True, exist_ok=True)
        summary = str(
            await summary_query_engine.aquery(
                "Extract a concise 1-2 line summary of this document"
            )
        )
        pickle.dump(summary, open(summary_out_path, "wb"))
    else:
        summary = pickle.load(open(summary_out_path, "rb"))
        
    query_tools = [
        QueryEngineTool(query_engine=vector_query_engine,
                        metadata=ToolMetadata(
                            name=f"vector_tool_{file_base}",
                            description=f"Useful for questions related to specific facts"
                )),
         QueryEngineTool(query_engine=summary_query_engine,
                        metadata=ToolMetadata(
                            name=f"summary_tool_{file_base}",
                            description=f"Useful for summarization questions",
                            )),

    ]
    
    function_llm = OpenAI(model="mistralai/Mixtral-8x7B-Instruct-v0.1")
 
    agent = OpenAIAgent.from_llm(
        llm=function_llm,
        tools=query_tools,
        verbose=True,
        # system_prompt=dedent(f"""\
        #     You are a specialized agent designed to answer queries about the `{file_base}.html` part of the LlamaIndex docs.
        #     You must ALWAYS use at least one of the tools provided when answering a question; do NOT rely on prior knowledge.\
        #     """),
    )
    
    return agent, summary

# %%
async def build_agents(docs):
    node_parser = SentenceSplitter()
    
    agents_dict = {}
    extract_info_dict = {}
    
    for idx, doc in enumerate(tqdm(docs)):
        nodes = node_parser.get_nodes_from_documents([doc])
        # ID will be base + parent
        file_path = Path(doc.metadata["path"])
        file_base = str(file_path.parent.stem) + "_" + str(file_path.stem)
        agent, summary = await build_agent_per_doc(nodes, file_base)
        
        agents_dict[file_base] = agent
        extract_info_dict[file_base] = {"summary": summary, "nodes": nodes}
        
    return agents_dict, extract_info_dict

# %%
agents_dict, extra_info_dict = await build_agents(docs[:7])
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# latest_index
#  14%|█▍        | 1/7 [00:09<00:58,  9.74s/it]
# latest_genindex

# %% [markdown]
# #### Next we will build the retreiver enabled OpenAI agent
# We are going to build the top level agent that orchestrates the use of the other agents to answer user queries

# %%
all_tools = []

for file_base, agent in agents_dict.items():
    summary = extra_info_dict[file_base]["summary"]
    doc_tool = QueryEngineTool(
        query_engine=agent, 
        metadata=ToolMetadata(
            name=f"tool_{file_base}",
            description=summary,
        )
    )
    all_tools.append(doc_tool)
